# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("../data/Train.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
## Prepare proposal document and final presentation.

# %%
# Question:
## 5w and h ## 
# 1. Which airline is most preffered airline.
# 2. Mean/Median price for which airline is highest and lowest.
# 3. For each flight which is the most common source and destination airport.
# 4. How many flights are going from each source airports and destination airport.
# 5. Which airline is having most non-stop flight.
# 6. Which day of week we have maximum and minimum flights?
# 7. During what time day we have more flights?
# 8. What is the average price for flights on each day of week?
#      a. Different hours of day [morning/afternoon/evening/night] what is the average price?
# 9. How price and duration of flight is varring?
# 10. For which source and destiantion you have maximum and minimum duration?

# %% [markdown]
# # Sanity Check

# %%
# check for duplicate data
# Date of Jorney is object need to be converted into Datetime.
# Dep_Time is fine.
# Arrival Time is incorrectly placed so need to fixed.
# Duration is available in HH:MM format need to be either in minutes or hours. checked
# Total_Stops should be numerical but right it is object.
# Check if Additional_Info column provides any meaning information or not.

# %%
len(df),len(df.drop_duplicates())
# Out:
# (10683, 10463)

# %%
10682 - 10460
# Out:
# 222

# %%
df[df.duplicated()].head()
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 683   Jet Airways       1/06/2019     Delhi      Cochin
# 1061    Air India      21/05/2019     Delhi      Cochin
# 1348    Air India      18/05/2019     Delhi      Cochin
# 1418  Jet Airways       6/06/2019     Delhi      Cochin
# 1674       IndiGo      24/03/2019  Banglore   New Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683   DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061  DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# 1348  DEL → HYD → BOM → COK    17:15  19:15 19 May      26h     2 stops
# 1418  DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1674              BLR → DEL    18:25         21:20   2h 55m    non-stop
#
#                   Additional_Info  Price
# 683                       No info  13376
# 1061                      No info  10231
# 1348                      No info  12392
# 1418  In-flight meal not included  10368
# 1674                      No info   7303

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 10463

# %%
# # 33,9261 #2283,9389
# df.iloc[[33,9260]]
# df.iloc[[2283,9388]]

# %%
def time_minute(duration):
    dur = duration.split()
    min = 0
    for x in dur:
        if x[-1] == 'h':
            min = min + int(x[:-1])*60

        if x[-1] == 'm':
            min = min + int(int(x[:-1])) 
    return min

def convert_duration_to_minutes(time):
    '''
    This function converts duration in h m to minutes:
    input : hh:mm ,hh, mm
    return:
        min
    '''
    if len(time.split(' ')) >1 :
        hh,mm = time.split(' ')
        hh,mm = int(hh[:-1]),int(mm[:-1])
        duration = hh*60+mm
    else:
        if 'h' in time:
            duration = int(time[:-1])*60
        else:
            duration= int(time[:-1])
            
    return duration

# %%
df['DepartureDateTime'] = df['Date_of_Journey'] + " "+ df['Dep_Time']
df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)

# %%
df['Duration_min'] = df['Duration'].apply(lambda x: convert_duration_to_minutes(x))

# %%
df['Duration_timedelta'] = pd.to_timedelta(df['Duration_min'], unit='m')

# %%
df["ArrivalDateTime"] = df['DepartureDateTime'] + df['Duration_timedelta']

# %%
df.drop(columns=['Date_of_Journey','Dep_Time','Arrival_Time','Duration'],axis=1,inplace=True)

# %%
stops_dict = {
    'non-stop':0,
    '2 stops':2,
    '1 stop':1,
    '3 stops':3,
    '4 stops':4
}
df['Total_Stops'] = df['Total_Stops'].replace(stops_dict)

# %%
df['Additional_Info'].value_counts()/len(df)*100
# Out:
# No info                         78.208927
# In-flight meal not included     18.407722
# No check-in baggage included     3.039281
# 1 Long layover                   0.181592
# Change airports                  0.066902
# Business class                   0.038230
# No Info                          0.028672
# 1 Short layover                  0.009557
# Red-eye flight                   0.009557
# 2 Long layover                   0.009557
# Name: Additional_Info, dtype: float64

# %%
# Additional Info columns doesnot have any meaningful information.
df.drop(columns=['Additional_Info'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Total_Stops  Price  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL          0.0   3897
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0   7662
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00
# 1 2019-05-01 05:50:00           445    0 days 07:25:00 2019-05-01 13:15:00

# %% [markdown]
# # Missing value Handling

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Total_Stops           1
# Price                 0
# DepartureDateTime     0
# Duration_min          0
# Duration_timedelta    0
# ArrivalDateTime       0
# dtype: int64

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route  Total_Stops  Price  \
# 9039  Air India  Delhi      Cochin   NaN          NaN   7480
#
#        DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime
# 9039 2019-05-06 09:45:00          1420    0 days 23:40:00 2019-05-07 09:25:00

# %%
# dropping Nan value as its a single observation.
df.dropna(inplace=True)

# %% [markdown]
# # Handling Categorical Values

# %%
# No order in columns
categorical_cols = ['Airline', 'Source', 'Destination', 'Route']
for col in categorical_cols:
    print("Column :",col," Unique values :",df[col].unique()," and No. of uniques : ",df[col].nunique())
    print("-"*90)
# Out:
# Column : Airline  Unique values : ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']  and No. of uniques :  12
# ------------------------------------------------------------------------------------------
# Column : Source  Unique values : ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']  and No. of uniques :  5
# ------------------------------------------------------------------------------------------
# Column : Destination  Unique values : ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']  and No. of uniques :  6
# ------------------------------------------------------------------------------------------
# Column : Route  Unique values : ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK'
#  'CCU → NAG → BLR' 'BLR → NAG → DEL' 'CCU → BLR' 'BLR → BOM → DEL'
#  'DEL → BOM → COK' 'DEL → BLR → COK' 'MAA → CCU' 'CCU → BOM → BLR'
#  'DEL → AMD → BOM → COK' 'DEL → PNQ → COK' 'DEL → CCU → BOM → COK'
#  'BLR → COK → DEL' 'DEL → IDR → BOM → COK' 'DEL → LKO → COK'
#  'CCU → GAU → DEL → BLR' 'DEL → NAG → BOM → COK' 'CCU → MAA → BLR'
#  'DEL → HYD → COK' 'CCU → HYD → BLR' 'DEL → COK' 'CCU → DEL → BLR'
#  'BLR → BOM → AMD → DEL' 'BOM → DEL → HYD' 'DEL → MAA → COK' 'BOM → HYD'
#  'DEL → BHO → BOM → COK' 'DEL → JAI → BOM → COK' 'DEL → ATQ → BOM → COK'
#  'DEL → JDH → BOM → COK' 'CCU → BBI → BOM → BLR' 'BLR → MAA → DEL'
#  'DEL → GOI → BOM → COK' 'DEL → BDQ → BOM → COK' 'CCU → JAI → BOM → BLR'
#  'CCU → BBI → BLR' 'BLR → HYD → DEL' 'DEL → TRV → COK'
#  'CCU → IXR → DEL → BLR' 'DEL → IXU → BOM → COK' 'CCU → IXB → BLR'
#  'BLR → BOM → JDH → DEL' 'DEL → UDR → BOM → COK' 'DEL → HYD → MAA → COK'
#  'CCU → BOM → COK → BLR' 'BLR → CCU → DEL' 'CCU → BOM → GOI → BLR'
#  'DEL → RPR → NAG → BOM → COK' 'DEL → HYD → BOM → COK'
#  'CCU → DEL → AMD → BLR' 'CCU → PNQ → BLR' 'BLR → CCU → GAU → DEL'
#  'CCU → DEL → COK → BLR' 'BLR → PNQ → DEL' 'BOM → JDH → DEL → HYD'
#  'BLR → BOM → BHO → DEL' 'DEL → AMD → COK' 'BLR → LKO → DEL'
#  'CCU → GAU → BLR' 'BOM → GOI → HYD' 'CCU → BOM → AMD → BLR'
#  'CCU → BBI → IXR → DEL → BLR' 'DEL → DED → BOM → COK'
#  'DEL → MAA → BOM → COK' 'BLR → AMD → DEL' 'BLR → VGA → DEL'
#  'CCU → JAI → DEL → BLR' 'CCU → AMD → BLR' 'CCU → VNS → DEL → BLR'
#  'BLR → BOM → IDR → DEL' 'BLR → BBI → DEL' 'BLR → GOI → DEL'
#  'BOM → AMD → ISK → HYD' 'BOM → DED → DEL → HYD' 'DEL → IXC → BOM → COK'
#  'CCU → PAT → BLR' 'BLR → CCU → BBI → DEL' 'CCU → BBI → HYD → BLR'
#  'BLR → BOM → NAG → DEL' 'BLR → CCU → BBI → HYD → DEL' 'BLR → GAU → DEL'
#  'BOM → BHO → DEL → HYD' 'BOM → JLR → HYD' 'BLR → HYD → VGA → DEL'
#  'CCU → KNU → BLR' 'CCU → BOM → PNQ → BLR' 'DEL → BBI → COK'
#  'BLR → VGA → HYD → DEL' 'BOM → JDH → JAI → DEL → HYD'
#  'DEL → GWL → IDR → BOM → COK' 'CCU → RPR → HYD → BLR' 'CCU → VTZ → BLR'
#  'CCU → DEL → VGA → BLR' 'BLR → BOM → IDR → GWL → DEL'
#  'CCU → DEL → COK → TRV → BLR' 'BOM → COK → MAA → HYD' 'BOM → NDC → HYD'
#  'BLR → BDQ → DEL' 'CCU → BOM → TRV → BLR' 'CCU → BOM → HBX → BLR'
#  'BOM → BDQ → DEL → HYD' 'BOM → CCU → HYD' 'BLR → TRV → COK → DEL'
#  'BLR → IDR → DEL' 'CCU → IXZ → MAA → BLR' 'CCU → GAU → IMF → DEL → BLR'
#  'BOM → GOI → PNQ → HYD' 'BOM → BLR → CCU → BBI → HYD' 'BOM → MAA → HYD'
#  'BLR → BOM → UDR → DEL' 'BOM → UDR → DEL → HYD' 'BLR → VGA → VTZ → DEL'
#  'BLR → HBX → BOM → BHO → DEL' 'CCU → IXA → BLR' 'BOM → RPR → VTZ → HYD'
#  'BLR → HBX → BOM → AMD → DEL' 'BOM → IDR → DEL → HYD' 'BOM → BLR → HYD'
#  'BLR → STV → DEL' 'CCU → IXB → DEL → BLR' 'BOM → JAI → DEL → HYD'
#  'BOM → VNS → DEL → HYD' 'BLR → HBX → BOM → NAG → DEL'
#  'BLR → BOM → IXC → DEL' 'BLR → CCU → BBI → HYD → VGA → DEL'
#  'BOM → BBI → HYD']  and No. of uniques :  128
# ------------------------------------------------------------------------------------------

# %%
df.head(1)
# Out:
#   Airline    Source Destination      Route  Total_Stops  Price  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL          0.0   3897
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00

# %%
df['Destination'] = df['Destination'].replace({'New Delhi':'Delhi'})

# %%
# No order in columns
categorical_cols = ['Airline', 'Source', 'Destination', 'Route']
for col in categorical_cols:
    print("Column :",col," Unique values :",df[col].unique()," and No. of uniques : ",df[col].nunique())
    print("-"*90)
# Out:
# Column : Airline  Unique values : ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']  and No. of uniques :  12
# ------------------------------------------------------------------------------------------
# Column : Source  Unique values : ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']  and No. of uniques :  5
# ------------------------------------------------------------------------------------------
# Column : Destination  Unique values : ['Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Hyderabad']  and No. of uniques :  5
# ------------------------------------------------------------------------------------------
# Column : Route  Unique values : ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK'
#  'CCU → NAG → BLR' 'BLR → NAG → DEL' 'CCU → BLR' 'BLR → BOM → DEL'
#  'DEL → BOM → COK' 'DEL → BLR → COK' 'MAA → CCU' 'CCU → BOM → BLR'
#  'DEL → AMD → BOM → COK' 'DEL → PNQ → COK' 'DEL → CCU → BOM → COK'
#  'BLR → COK → DEL' 'DEL → IDR → BOM → COK' 'DEL → LKO → COK'
#  'CCU → GAU → DEL → BLR' 'DEL → NAG → BOM → COK' 'CCU → MAA → BLR'
#  'DEL → HYD → COK' 'CCU → HYD → BLR' 'DEL → COK' 'CCU → DEL → BLR'
#  'BLR → BOM → AMD → DEL' 'BOM → DEL → HYD' 'DEL → MAA → COK' 'BOM → HYD'
#  'DEL → BHO → BOM → COK' 'DEL → JAI → BOM → COK' 'DEL → ATQ → BOM → COK'
#  'DEL → JDH → BOM → COK' 'CCU → BBI → BOM → BLR' 'BLR → MAA → DEL'
#  'DEL → GOI → BOM → COK' 'DEL → BDQ → BOM → COK' 'CCU → JAI → BOM → BLR'
#  'CCU → BBI → BLR' 'BLR → HYD → DEL' 'DEL → TRV → COK'
#  'CCU → IXR → DEL → BLR' 'DEL → IXU → BOM → COK' 'CCU → IXB → BLR'
#  'BLR → BOM → JDH → DEL' 'DEL → UDR → BOM → COK' 'DEL → HYD → MAA → COK'
#  'CCU → BOM → COK → BLR' 'BLR → CCU → DEL' 'CCU → BOM → GOI → BLR'
#  'DEL → RPR → NAG → BOM → COK' 'DEL → HYD → BOM → COK'
#  'CCU → DEL → AMD → BLR' 'CCU → PNQ → BLR' 'BLR → CCU → GAU → DEL'
#  'CCU → DEL → COK → BLR' 'BLR → PNQ → DEL' 'BOM → JDH → DEL → HYD'
#  'BLR → BOM → BHO → DEL' 'DEL → AMD → COK' 'BLR → LKO → DEL'
#  'CCU → GAU → BLR' 'BOM → GOI → HYD' 'CCU → BOM → AMD → BLR'
#  'CCU → BBI → IXR → DEL → BLR' 'DEL → DED → BOM → COK'
#  'DEL → MAA → BOM → COK' 'BLR → AMD → DEL' 'BLR → VGA → DEL'
#  'CCU → JAI → DEL → BLR' 'CCU → AMD → BLR' 'CCU → VNS → DEL → BLR'
#  'BLR → BOM → IDR → DEL' 'BLR → BBI → DEL' 'BLR → GOI → DEL'
#  'BOM → AMD → ISK → HYD' 'BOM → DED → DEL → HYD' 'DEL → IXC → BOM → COK'
#  'CCU → PAT → BLR' 'BLR → CCU → BBI → DEL' 'CCU → BBI → HYD → BLR'
#  'BLR → BOM → NAG → DEL' 'BLR → CCU → BBI → HYD → DEL' 'BLR → GAU → DEL'
#  'BOM → BHO → DEL → HYD' 'BOM → JLR → HYD' 'BLR → HYD → VGA → DEL'
#  'CCU → KNU → BLR' 'CCU → BOM → PNQ → BLR' 'DEL → BBI → COK'
#  'BLR → VGA → HYD → DEL' 'BOM → JDH → JAI → DEL → HYD'
#  'DEL → GWL → IDR → BOM → COK' 'CCU → RPR → HYD → BLR' 'CCU → VTZ → BLR'
#  'CCU → DEL → VGA → BLR' 'BLR → BOM → IDR → GWL → DEL'
#  'CCU → DEL → COK → TRV → BLR' 'BOM → COK → MAA → HYD' 'BOM → NDC → HYD'
#  'BLR → BDQ → DEL' 'CCU → BOM → TRV → BLR' 'CCU → BOM → HBX → BLR'
#  'BOM → BDQ → DEL → HYD' 'BOM → CCU → HYD' 'BLR → TRV → COK → DEL'
#  'BLR → IDR → DEL' 'CCU → IXZ → MAA → BLR' 'CCU → GAU → IMF → DEL → BLR'
#  'BOM → GOI → PNQ → HYD' 'BOM → BLR → CCU → BBI → HYD' 'BOM → MAA → HYD'
#  'BLR → BOM → UDR → DEL' 'BOM → UDR → DEL → HYD' 'BLR → VGA → VTZ → DEL'
#  'BLR → HBX → BOM → BHO → DEL' 'CCU → IXA → BLR' 'BOM → RPR → VTZ → HYD'
#  'BLR → HBX → BOM → AMD → DEL' 'BOM → IDR → DEL → HYD' 'BOM → BLR → HYD'
#  'BLR → STV → DEL' 'CCU → IXB → DEL → BLR' 'BOM → JAI → DEL → HYD'
#  'BOM → VNS → DEL → HYD' 'BLR → HBX → BOM → NAG → DEL'
#  'BLR → BOM → IXC → DEL' 'BLR → CCU → BBI → HYD → VGA → DEL'
#  'BOM → BBI → HYD']  and No. of uniques :  128
# ------------------------------------------------------------------------------------------

# %%
def frequency_encoder(df,col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          frequency encoded dictionary for columns
    """
    freq_value = df.groupby(col).size()/len(df)
    freq_dict = freq_value.to_dict()
    df["Freq_encoded_"+col] = df[col].replace(freq_dict)
    return freq_dict

# %%
def mean_encoder(df,col,target_col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          Mean encoded dict for column
    """
    mean_value = df.groupby(col)[target_col].mean()
    mean_dict = mean_value.to_dict()
    df["Mean_encoded_"+col] = df[col].replace(mean_dict)
    return mean_dict

# %%
## Label encoder for function and later usages:

## Applying Label Encoder to Categorical columns as Hit and Trail.
from sklearn.preprocessing import LabelEncoder

def label_encoder(df,col):
    """
    This function encodes a categorical column based on the basis of their order label.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          label encoded dict for column
    """
    le = LabelEncoder()
    le.fit(df[col])
    label_dict = dict(zip((le.classes_),le.transform(le.classes_)))
    df["Label_encoded_"+col] = df[col].replace(label_dict)
    return label_dict

# %%
## Create a function to handle categorical value
def handle_categorical_values(df,target):
    '''
      This function handles categorical value and create a dataframe.
      Input:
        df : Dataframe which require categorical value treatment
      returns :
         Dataframe with all categorical value handled.
    '''
    encoded_dict = {}
    # Getting all object columns
    object_columns = df.select_dtypes(object).columns

    ## generate frequency encoded categorical values
    frequency_encoded_dict ={} 
    for col in object_columns:
        freq_dict = frequency_encoder(df,col)
        frequency_encoded_dict[col] = freq_dict

    ## generate target mean encoded categorical values
    mean_encoded_dict ={} 
    for col in object_columns:
        mean_dict = mean_encoder(df,col,target)
        mean_encoded_dict[col] = mean_dict

    
    ## generate label encoded categorical values
    label_encoded_dict ={} 
    for col in object_columns:
        label_dict = label_encoder(df,col)
        label_encoded_dict[col] = label_dict
    
    encoded_dict["Frequency"] = frequency_encoded_dict
    encoded_dict["Mean"] = mean_encoded_dict
    encoded_dict["Label"] = label_encoded_dict

    return df, encoded_dict

# %%
target = 'Price'
df, encoded_dict = handle_categorical_values(df,target)

# %%
encoded_dict
# Out:
# {'Frequency': {'Airline': {'Air Asia': 0.030491301854329956,
#    'Air India': 0.1619193270885108,
#    'GoAir': 0.018543299560313517,
#    'IndiGo': 0.1952781494934047,
#    'Jet Airways': 0.35366086790288664,
#    'Jet Airways Business': 0.0005735041101127892,
#    'Multiple carriers': 0.1143184859491493,
#    'Multiple carriers Premium economy': 0.0012425922385777097,
#    'SpiceJet': 0.0779009749569872,
#    'Trujet': 9.558401835213153e-05,
#    'Vistara': 0.04568916077231887,
#    'Vistara Premium economy': 0.0002867520550563946},
#   'Source': {'Banglore': 0.20827757598929458,
#    'Chennai': 0.03641751099216211,
#    'Delhi': 0.41531255974001147,
#    'Kolkata': 0.27337029248709616,
#    'Mumbai': 0.06662206079143568},
#   'Destination': {'Banglore': 0.27337029248709616,
#    'Cochin': 0.41531255974001147,
#    'Delhi': 0.20827757598929458,
#    'Hyderabad': 0.06662206079143568,
#    'Kolkata': 0.03641751099216211},
#   'Route': {'BLR → AMD → DEL': 0.0017205123303383673,
#    'BLR → BBI → DEL': 0.0004779200917606576,
#    'BLR → BDQ → DEL': 0.0007646721468170522,
#    'BLR → BOM → AMD → DEL': 0.0003823360734085261,
#    'BLR → BOM → BHO → DEL': 0.0010514242018734468,
#    'BLR → BOM → DEL': 0.038424775377556876,
#    'BLR → BOM → IDR → DEL': 0.0004779200917606576,
#    'BLR → BOM → IDR → GWL → DEL': 0.00019116803670426305,
#    'BLR → BOM → IXC → DEL': 9.558401835213153e-05,
#    'BLR → BOM → JDH → DEL': 0.0005735041101127892,
#    'BLR → BOM → NAG → DEL': 0.0008602561651691837,
#    'BLR → BOM → UDR → DEL': 0.0002867520550563946,
#    'BLR → CCU → BBI → DEL': 0.0004779200917606576,
#    'BLR → CCU → BBI → HYD → DEL': 0.00019116803670426305,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 9.558401835213153e-05,
#    'BLR → CCU → DEL': 0.0010514242018734468,
#    'BLR → CCU → GAU → DEL': 0.0010514242018734468,
#    'BLR → COK → DEL': 0.0014337602752819729,
#    'BLR → DEL': 0.14681705218887403,
#    'BLR → GAU → DEL': 0.0002867520550563946,
#    'BLR → GOI → DEL': 0.0006690881284649206,
#    'BLR → HBX → BOM → AMD → DEL': 9.558401835213153e-05,
#    'BLR → HBX → BOM → BHO → DEL': 9.558401835213153e-05,
#    'BLR → HBX → BOM → NAG → DEL': 9.558401835213153e-05,
#    'BLR → HYD → DEL': 0.0035366086790288662,
#    'BLR → HYD → VGA → DEL': 0.0009558401835213152,
#    'BLR → IDR → DEL': 0.0004779200917606576,
#    'BLR → LKO → DEL': 0.0002867520550563946,
#    'BLR → MAA → DEL': 0.002771936532211814,
#    'BLR → NAG → DEL': 0.0002867520550563946,
#    'BLR → PNQ → DEL': 0.0004779200917606576,
#    'BLR → STV → DEL': 0.00019116803670426305,
#    'BLR → TRV → COK → DEL': 0.00019116803670426305,
#    'BLR → VGA → DEL': 0.0008602561651691837,
#    'BLR → VGA → HYD → DEL': 0.0003823360734085261,
#    'BLR → VGA → VTZ → DEL': 0.00019116803670426305,
#    'BOM → AMD → ISK → HYD': 0.0003823360734085261,
#    'BOM → BBI → HYD': 9.558401835213153e-05,
#    'BOM → BDQ → DEL → HYD': 0.00019116803670426305,
#    'BOM → BHO → DEL → HYD': 0.0006690881284649206,
#    'BOM → BLR → CCU → BBI → HYD': 9.558401835213153e-05,
#    'BOM → BLR → HYD': 0.0002867520550563946,
#    'BOM → CCU → HYD': 9.558401835213153e-05,
#    'BOM → COK → MAA → HYD': 9.558401835213153e-05,
#    'BOM → DED → DEL → HYD': 9.558401835213153e-05,
#    'BOM → DEL → HYD': 0.0031542726056203404,
#    'BOM → GOI → HYD': 9.558401835213153e-05,
#    'BOM → GOI → PNQ → HYD': 0.0005735041101127892,
#    'BOM → HYD': 0.05935767539667368,
#    'BOM → IDR → DEL → HYD': 0.00019116803670426305,
#    'BOM → JAI → DEL → HYD': 9.558401835213153e-05,
#    'BOM → JDH → DEL → HYD': 0.0002867520550563946,
#    'BOM → JDH → JAI → DEL → HYD': 9.558401835213153e-05,
#    'BOM → JLR → HYD': 9.558401835213153e-05,
#    'BOM → MAA → HYD': 0.0002867520550563946,
#    'BOM → NDC → HYD': 9.558401835213153e-05,
#    'BOM → RPR → VTZ → HYD': 9.558401835213153e-05,
#    'BOM → UDR → DEL → HYD': 9.558401835213153e-05,
#    'BOM → VNS → DEL → HYD': 9.558401835213153e-05,
#    'CCU → AMD → BLR': 0.0010514242018734468,
#    'CCU → BBI → BLR': 0.004779200917606577,
#    'CCU → BBI → BOM → BLR': 0.004014528770789524,
#    'CCU → BBI → HYD → BLR': 0.0008602561651691837,
#    'CCU → BBI → IXR → DEL → BLR': 0.00019116803670426305,
#    'CCU → BLR': 0.06920282928694323,
#    'CCU → BOM → AMD → BLR': 0.0008602561651691837,
#    'CCU → BOM → BLR': 0.09357675396673676,
#    'CCU → BOM → COK → BLR': 0.0028675205505639457,
#    'CCU → BOM → GOI → BLR': 0.0012425922385777097,
#    'CCU → BOM → HBX → BLR': 0.0005735041101127892,
#    'CCU → BOM → PNQ → BLR': 0.0003823360734085261,
#    'CCU → BOM → TRV → BLR': 0.00019116803670426305,
#    'CCU → DEL → AMD → BLR': 0.002007264385394762,
#    'CCU → DEL → BLR': 0.05400497036895431,
#    'CCU → DEL → COK → BLR': 0.002771936532211814,
#    'CCU → DEL → COK → TRV → BLR': 0.0003823360734085261,
#    'CCU → DEL → VGA → BLR': 0.0003823360734085261,
#    'CCU → GAU → BLR': 0.0039189447524373925,
#    'CCU → GAU → DEL → BLR': 0.003632192697380998,
#    'CCU → GAU → IMF → DEL → BLR': 0.0004779200917606576,
#    'CCU → HYD → BLR': 0.0050659529726629704,
#    'CCU → IXA → BLR': 9.558401835213153e-05,
#    'CCU → IXB → BLR': 0.0019116803670426305,
#    'CCU → IXB → DEL → BLR': 9.558401835213153e-05,
#    'CCU → IXR → BBI → BLR': 0.0005735041101127892,
#    'CCU → IXR → DEL → BLR': 0.00439686484419805,
#    'CCU → IXZ → MAA → BLR': 9.558401835213153e-05,
#    'CCU → JAI → BOM → BLR': 0.0012425922385777097,
#    'CCU → JAI → DEL → BLR': 0.0005735041101127892,
#    'CCU → KNU → BLR': 0.0009558401835213152,
#    'CCU → MAA → BLR': 0.006212961192888549,
#    'CCU → NAG → BLR': 0.0008602561651691837,
#    'CCU → PAT → BLR': 0.0009558401835213152,
#    'CCU → PNQ → BLR': 0.001816096348690499,
#    'CCU → RPR → HYD → BLR': 9.558401835213153e-05,
#    'CCU → VNS → DEL → BLR': 0.0009558401835213152,
#    'CCU → VTZ → BLR': 9.558401835213153e-05,
#    'DEL → AMD → BOM → COK': 0.013764098642706939,
#    'DEL → AMD → COK': 0.0023896004588032883,
#    'DEL → ATQ → BOM → COK': 0.003823360734085261,
#    'DEL → BBI → COK': 0.0004779200917606576,
#    'DEL → BDQ → BOM → COK': 0.002580768495507551,
#    'DEL → BHO → BOM → COK': 0.0045880328809023135,
#    'DEL → BLR → COK': 0.022175492257694513,
#    'DEL → BOM → COK': 0.2271076276046645,
#    'DEL → CCU → BOM → COK': 0.004205696807493787,
#    'DEL → COK': 0.020359395909004013,
#    'DEL → DED → BOM → COK': 0.00019116803670426305,
#    'DEL → GOI → BOM → COK': 0.004205696807493787,
#    'DEL → GWL → IDR → BOM → COK': 0.0007646721468170522,
#    'DEL → HYD → BOM → COK': 0.004301280825845919,
#    'DEL → HYD → COK': 0.031160389982794877,
#    'DEL → HYD → MAA → COK': 0.007933473523226917,
#    'DEL → IDR → BOM → COK': 0.008602561651691838,
#    'DEL → IXC → BOM → COK': 0.0010514242018734468,
#    'DEL → IXU → BOM → COK': 0.0011470082202255784,
#    'DEL → JAI → BOM → COK': 0.01749187535844007,
#    'DEL → JDH → BOM → COK': 0.0035366086790288662,
#    'DEL → LKO → BOM → COK': 0.0039189447524373925,
#    'DEL → LKO → COK': 0.001624928311986236,
#    'DEL → MAA → BOM → COK': 0.0010514242018734468,
#    'DEL → MAA → COK': 0.013955266679411202,
#    'DEL → NAG → BOM → COK': 0.004205696807493787,
#    'DEL → PNQ → COK': 0.004014528770789524,
#    'DEL → RPR → NAG → BOM → COK': 0.0014337602752819729,
#    'DEL → TRV → COK': 0.0015293442936341044,
#    'DEL → UDR → BOM → COK': 0.0017205123303383673,
#    'MAA → CCU': 0.03641751099216211}},
#  'Mean': {'Airline': {'Air Asia': 5590.260188087775,
#    'Air India': 9556.6080283353,
#    'GoAir': 5861.056701030928,
#    'IndiGo': 5668.469897209985,
#    'Jet Airways': 11599.02108108108,
#    'Jet Airways Business': 58358.666666666664,
#    'Multiple carriers': 10902.678093645485,
#    'Multiple carriers Premium economy': 11418.846153846154,
#    'SpiceJet': 4335.841717791411,
#    'Trujet': 4140.0,
#    'Vistara': 7801.355648535565,
#    'Vistara Premium economy': 8962.333333333334},
#   'Source': {'Banglore': 8022.872877466728,
#    'Chennai': 4789.892388451443,
#    'Delhi': 10461.600690448791,
#    'Kolkata': 9143.083566433566,
#    'Mumbai': 5059.708751793401},
#   'Destination': {'Banglore': 9143.083566433566,
#    'Cochin': 10461.600690448791,
#    'Delhi': 8022.872877466728,
#    'Hyderabad': 5059.708751793401,
#    'Kolkata': 4789.892388451443},
#   'Route': {'BLR → AMD → DEL': 11134.166666666666,
#    'BLR → BBI → DEL': 11486.0,
#    'BLR → BDQ → DEL': 11550.5,
#    'BLR → BOM → AMD → DEL': 14155.75,
#    'BLR → BOM → BHO → DEL': 17211.545454545456,
#    'BLR → BOM → DEL': 15723.174129353234,
#    'BLR → BOM → IDR → DEL': 15360.6,
#    'BLR → BOM → IDR → GWL → DEL': 13387.0,
#    'BLR → BOM → IXC → DEL': 13303.0,
#    'BLR → BOM → JDH → DEL': 14845.833333333334,
#    'BLR → BOM → NAG → DEL': 14685.333333333334,
#    'BLR → BOM → UDR → DEL': 11937.666666666666,
#    'BLR → CCU → BBI → DEL': 9155.0,
#    'BLR → CCU → BBI → HYD → DEL': 12713.5,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 17686.0,
#    'BLR → CCU → DEL': 12260.272727272728,
#    'BLR → CCU → GAU → DEL': 11810.0,
#    'BLR → COK → DEL': 9139.133333333333,
#    'BLR → DEL': 5552.235677083333,
#    'BLR → GAU → DEL': 12508.333333333334,
#    'BLR → GOI → DEL': 8759.857142857143,
#    'BLR → HBX → BOM → AMD → DEL': 10573.0,
#    'BLR → HBX → BOM → BHO → DEL': 14195.0,
#    'BLR → HBX → BOM → NAG → DEL': 12358.0,
#    'BLR → HYD → DEL': 6473.027027027027,
#    'BLR → HYD → VGA → DEL': 10770.7,
#    'BLR → IDR → DEL': 7610.4,
#    'BLR → LKO → DEL': 7334.333333333333,
#    'BLR → MAA → DEL': 12071.965517241379,
#    'BLR → NAG → DEL': 11313.0,
#    'BLR → PNQ → DEL': 11888.4,
#    'BLR → STV → DEL': 5746.0,
#    'BLR → TRV → COK → DEL': 11838.0,
#    'BLR → VGA → DEL': 9002.222222222223,
#    'BLR → VGA → HYD → DEL': 9598.75,
#    'BLR → VGA → VTZ → DEL': 15361.0,
#    'BOM → AMD → ISK → HYD': 11762.0,
#    'BOM → BBI → HYD': 14408.0,
#    'BOM → BDQ → DEL → HYD': 22792.5,
#    'BOM → BHO → DEL → HYD': 13161.57142857143,
#    'BOM → BLR → CCU → BBI → HYD': 14260.0,
#    'BOM → BLR → HYD': 9045.0,
#    'BOM → CCU → HYD': 16666.0,
#    'BOM → COK → MAA → HYD': 9678.0,
#    'BOM → DED → DEL → HYD': 24115.0,
#    'BOM → DEL → HYD': 13379.515151515152,
#    'BOM → GOI → HYD': 7681.0,
#    'BOM → GOI → PNQ → HYD': 17082.0,
#    'BOM → HYD': 3932.8099838969406,
#    'BOM → IDR → DEL → HYD': 17049.0,
#    'BOM → JAI → DEL → HYD': 17926.0,
#    'BOM → JDH → DEL → HYD': 23867.0,
#    'BOM → JDH → JAI → DEL → HYD': 18293.0,
#    'BOM → JLR → HYD': 13552.0,
#    'BOM → MAA → HYD': 8598.333333333334,
#    'BOM → NDC → HYD': 4140.0,
#    'BOM → RPR → VTZ → HYD': 9736.0,
#    'BOM → UDR → DEL → HYD': 22950.0,
#    'BOM → VNS → DEL → HYD': 23528.0,
#    'CCU → AMD → BLR': 8382.636363636364,
#    'CCU → BBI → BLR': 6060.6,
#    'CCU → BBI → BOM → BLR': 10457.404761904761,
#    'CCU → BBI → HYD → BLR': 5790.333333333333,
#    'CCU → BBI → IXR → DEL → BLR': 12606.0,
#    'CCU → BLR': 4556.055248618784,
#    'CCU → BOM → AMD → BLR': 14424.444444444445,
#    'CCU → BOM → BLR': 11487.788559754852,
#    'CCU → BOM → COK → BLR': 12864.833333333334,
#    'CCU → BOM → GOI → BLR': 11809.76923076923,
#    'CCU → BOM → HBX → BLR': 10037.166666666666,
#    'CCU → BOM → PNQ → BLR': 10118.0,
#    'CCU → BOM → TRV → BLR': 12403.0,
#    'CCU → DEL → AMD → BLR': 13719.095238095239,
#    'CCU → DEL → BLR': 10763.258407079646,
#    'CCU → DEL → COK → BLR': 13486.241379310344,
#    'CCU → DEL → COK → TRV → BLR': 12941.25,
#    'CCU → DEL → VGA → BLR': 12533.25,
#    'CCU → GAU → BLR': 7612.682926829269,
#    'CCU → GAU → DEL → BLR': 13892.052631578947,
#    'CCU → GAU → IMF → DEL → BLR': 13537.4,
#    'CCU → HYD → BLR': 4910.018867924528,
#    'CCU → IXA → BLR': 9413.0,
#    'CCU → IXB → BLR': 9275.25,
#    'CCU → IXB → DEL → BLR': 15292.0,
#    'CCU → IXR → BBI → BLR': 7369.166666666667,
#    'CCU → IXR → DEL → BLR': 10969.065217391304,
#    'CCU → IXZ → MAA → BLR': 11522.0,
#    'CCU → JAI → BOM → BLR': 10874.692307692309,
#    'CCU → JAI → DEL → BLR': 12053.0,
#    'CCU → KNU → BLR': 8623.4,
#    'CCU → MAA → BLR': 5240.876923076923,
#    'CCU → NAG → BLR': 6279.333333333333,
#    'CCU → PAT → BLR': 10821.3,
#    'CCU → PNQ → BLR': 6703.421052631579,
#    'CCU → RPR → HYD → BLR': 6103.0,
#    'CCU → VNS → DEL → BLR': 15164.5,
#    'CCU → VTZ → BLR': 6301.0,
#    'DEL → AMD → BOM → COK': 12630.173611111111,
#    'DEL → AMD → COK': 5606.2,
#    'DEL → ATQ → BOM → COK': 16699.675,
#    'DEL → BBI → COK': 11062.6,
#    'DEL → BDQ → BOM → COK': 12339.444444444445,
#    'DEL → BHO → BOM → COK': 14120.645833333334,
#    'DEL → BLR → COK': 7559.612068965517,
#    'DEL → BOM → COK': 10954.205808080807,
#    'DEL → CCU → BOM → COK': 13962.431818181818,
#    'DEL → COK': 6315.816901408451,
#    'DEL → DED → BOM → COK': 19539.5,
#    'DEL → GOI → BOM → COK': 11941.818181818182,
#    'DEL → GWL → IDR → BOM → COK': 17292.75,
#    'DEL → HYD → BOM → COK': 11724.577777777778,
#    'DEL → HYD → COK': 7299.331288343558,
#    'DEL → HYD → MAA → COK': 9133.469879518072,
#    'DEL → IDR → BOM → COK': 14038.122222222222,
#    'DEL → IXC → BOM → COK': 12514.545454545454,
#    'DEL → IXU → BOM → COK': 19381.333333333332,
#    'DEL → JAI → BOM → COK': 12210.196721311475,
#    'DEL → JDH → BOM → COK': 16163.135135135135,
#    'DEL → LKO → BOM → COK': 13277.19512195122,
#    'DEL → LKO → COK': 7166.176470588235,
#    'DEL → MAA → BOM → COK': 9161.636363636364,
#    'DEL → MAA → COK': 7312.431506849315,
#    'DEL → NAG → BOM → COK': 12171.227272727272,
#    'DEL → PNQ → COK': 6602.071428571428,
#    'DEL → RPR → NAG → BOM → COK': 11021.533333333333,
#    'DEL → TRV → COK': 7835.625,
#    'DEL → UDR → BOM → COK': 13859.277777777777,
#    'MAA → CCU': 4789.892388451443}},
#  'Label': {'Airline': {'Air Asia': 0,
#    'Air India': 1,
#    'GoAir': 2,
#    'IndiGo': 3,
#    'Jet Airways': 4,
#    'Jet Airways Business': 5,
#    'Multiple carriers': 6,
#    'Multiple carriers Premium economy': 7,
#    'SpiceJet': 8,
#    'Trujet': 9,
#    'Vistara': 10,
#    'Vistara Premium economy': 11},
#   'Source': {'Banglore': 0,
#    'Chennai': 1,
#    'Delhi': 2,
#    'Kolkata': 3,
#    'Mumbai': 4},
#   'Destination': {'Banglore': 0,
#    'Cochin': 1,
#    'Delhi': 2,
#    'Hyderabad': 3,
#    'Kolkata': 4},
#   'Route': {'BLR → AMD → DEL': 0,
#    'BLR → BBI → DEL': 1,
#    'BLR → BDQ → DEL': 2,
#    'BLR → BOM → AMD → DEL': 3,
#    'BLR → BOM → BHO → DEL': 4,
#    'BLR → BOM → DEL': 5,
#    'BLR → BOM → IDR → DEL': 6,
#    'BLR → BOM → IDR → GWL → DEL': 7,
#    'BLR → BOM → IXC → DEL': 8,
#    'BLR → BOM → JDH → DEL': 9,
#    'BLR → BOM → NAG → DEL': 10,
#    'BLR → BOM → UDR → DEL': 11,
#    'BLR → CCU → BBI → DEL': 12,
#    'BLR → CCU → BBI → HYD → DEL': 13,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 14,
#    'BLR → CCU → DEL': 15,
#    'BLR → CCU → GAU → DEL': 16,
#    'BLR → COK → DEL': 17,
#    'BLR → DEL': 18,
#    'BLR → GAU → DEL': 19,
#    'BLR → GOI → DEL': 20,
#    'BLR → HBX → BOM → AMD → DEL': 21,
#    'BLR → HBX → BOM → BHO → DEL': 22,
#    'BLR → HBX → BOM → NAG → DEL': 23,
#    'BLR → HYD → DEL': 24,
#    'BLR → HYD → VGA → DEL': 25,
#    'BLR → IDR → DEL': 26,
#    'BLR → LKO → DEL': 27,
#    'BLR → MAA → DEL': 28,
#    'BLR → NAG → DEL': 29,
#    'BLR → PNQ → DEL': 30,
#    'BLR → STV → DEL': 31,
#    'BLR → TRV → COK → DEL': 32,
#    'BLR → VGA → DEL': 33,
#    'BLR → VGA → HYD → DEL': 34,
#    'BLR → VGA → VTZ → DEL': 35,
#    'BOM → AMD → ISK → HYD': 36,
#    'BOM → BBI → HYD': 37,
#    'BOM → BDQ → DEL → HYD': 38,
#    'BOM → BHO → DEL → HYD': 39,
#    'BOM → BLR → CCU → BBI → HYD': 40,
#    'BOM → BLR → HYD': 41,
#    'BOM → CCU → HYD': 42,
#    'BOM → COK → MAA → HYD': 43,
#    'BOM → DED → DEL → HYD': 44,
#    'BOM → DEL → HYD': 45,
#    'BOM → GOI → HYD': 46,
#    'BOM → GOI → PNQ → HYD': 47,
#    'BOM → HYD': 48,
#    'BOM → IDR → DEL → HYD': 49,
#    'BOM → JAI → DEL → HYD': 50,
#    'BOM → JDH → DEL → HYD': 51,
#    'BOM → JDH → JAI → DEL → HYD': 52,
#    'BOM → JLR → HYD': 53,
#    'BOM → MAA → HYD': 54,
#    'BOM → NDC → HYD': 55,
#    'BOM → RPR → VTZ → HYD': 56,
#    'BOM → UDR → DEL → HYD': 57,
#    'BOM → VNS → DEL → HYD': 58,
#    'CCU → AMD → BLR': 59,
#    'CCU → BBI → BLR': 60,
#    'CCU → BBI → BOM → BLR': 61,
#    'CCU → BBI → HYD → BLR': 62,
#    'CCU → BBI → IXR → DEL → BLR': 63,
#    'CCU → BLR': 64,
#    'CCU → BOM → AMD → BLR': 65,
#    'CCU → BOM → BLR': 66,
#    'CCU → BOM → COK → BLR': 67,
#    'CCU → BOM → GOI → BLR': 68,
#    'CCU → BOM → HBX → BLR': 69,
#    'CCU → BOM → PNQ → BLR': 70,
#    'CCU → BOM → TRV → BLR': 71,
#    'CCU → DEL → AMD → BLR': 72,
#    'CCU → DEL → BLR': 73,
#    'CCU → DEL → COK → BLR': 74,
#    'CCU → DEL → COK → TRV → BLR': 75,
#    'CCU → DEL → VGA → BLR': 76,
#    'CCU → GAU → BLR': 77,
#    'CCU → GAU → DEL → BLR': 78,
#    'CCU → GAU → IMF → DEL → BLR': 79,
#    'CCU → HYD → BLR': 80,
#    'CCU → IXA → BLR': 81,
#    'CCU → IXB → BLR': 82,
#    'CCU → IXB → DEL → BLR': 83,
#    'CCU → IXR → BBI → BLR': 84,
#    'CCU → IXR → DEL → BLR': 85,
#    'CCU → IXZ → MAA → BLR': 86,
#    'CCU → JAI → BOM → BLR': 87,
#    'CCU → JAI → DEL → BLR': 88,
#    'CCU → KNU → BLR': 89,
#    'CCU → MAA → BLR': 90,
#    'CCU → NAG → BLR': 91,
#    'CCU → PAT → BLR': 92,
#    'CCU → PNQ → BLR': 93,
#    'CCU → RPR → HYD → BLR': 94,
#    'CCU → VNS → DEL → BLR': 95,
#    'CCU → VTZ → BLR': 96,
#    'DEL → AMD → BOM → COK': 97,
#    'DEL → AMD → COK': 98,
#    'DEL → ATQ → BOM → COK': 99,
#    'DEL → BBI → COK': 100,
#    'DEL → BDQ → BOM → COK': 101,
#    'DEL → BHO → BOM → COK': 102,
#    'DEL → BLR → COK': 103,
#    'DEL → BOM → COK': 104,
#    'DEL → CCU → BOM → COK': 105,
#    'DEL → COK': 106,
#    'DEL → DED → BOM → COK': 107,
#    'DEL → GOI → BOM → COK': 108,
#    'DEL → GWL → IDR → BOM → COK': 109,
#    'DEL → HYD → BOM → COK': 110,
#    'DEL → HYD → COK': 111,
#    'DEL → HYD → MAA → COK': 112,
#    'DEL → IDR → BOM → COK': 113,
#    'DEL → IXC → BOM → COK': 114,
#    'DEL → IXU → BOM → COK': 115,
#    'DEL → JAI → BOM → COK': 116,
#    'DEL → JDH → BOM → COK': 117,
#    'DEL → LKO → BOM → COK': 118,
#    'DEL → LKO → COK': 119,
#    'DEL → MAA → BOM → COK': 120,
#    'DEL → MAA → COK': 121,
#    'DEL → NAG → BOM → COK': 122,
#    'DEL → PNQ → COK': 123,
#    'DEL → RPR → NAG → BOM → COK': 124,
#    'DEL → TRV → COK': 125,
#    'DEL → UDR → BOM → COK': 126,
#    'MAA → CCU': 127}}}

# %%
df
# Out:
#            Airline    Source Destination                  Route  Total_Stops  \
# 0           IndiGo  Banglore       Delhi              BLR → DEL          0.0
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4           IndiGo  Banglore       Delhi        BLR → NAG → DEL          1.0
# ...            ...       ...         ...                    ...          ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR          0.0
# 10679    Air India   Kolkata    Banglore              CCU → BLR          0.0
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL          0.0
# 10681      Vistara  Banglore       Delhi              BLR → DEL          0.0
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK          2.0
#
#        Price   DepartureDateTime  Duration_min Duration_timedelta  \
# 0       3897 2019-03-24 22:20:00           170    0 days 02:50:00
# 1       7662 2019-05-01 05:50:00           445    0 days 07:25:00
# 2      13882 2019-06-09 09:25:00          1140    0 days 19:00:00
# 3       6218 2019-05-12 18:05:00           325    0 days 05:25:00
# 4      13302 2019-03-01 16:50:00           285    0 days 04:45:00
# ...      ...                 ...           ...                ...
# 10678   4107 2019-04-09 19:55:00           150    0 days 02:30:00
# 10679   4145 2019-04-27 20:45:00           155    0 days 02:35:00
# 10680   7229 2019-04-27 08:20:00           180    0 days 03:00:00
# 10681  12648 2019-03-01 11:30:00           160    0 days 02:40:00
# 10682  11753 2019-05-09 10:55:00           500    0 days 08:20:00
#
#           ArrivalDateTime  ...  Freq_encoded_Destination  Freq_encoded_Route  \
# 0     2019-03-25 01:10:00  ...                  0.208278            0.146817
# 1     2019-05-01 13:15:00  ...                  0.273370            0.000574
# 2     2019-06-10 04:25:00  ...                  0.415313            0.003919
# 3     2019-05-12 23:30:00  ...                  0.273370            0.000860
# 4     2019-03-01 21:35:00  ...                  0.208278            0.000287
# ...                   ...  ...                       ...                 ...
# 10678 2019-04-09 22:25:00  ...                  0.273370            0.069203
# 10679 2019-04-27 23:20:00  ...                  0.273370            0.069203
# 10680 2019-04-27 11:20:00  ...                  0.208278            0.146817
# 10681 2019-03-01 14:10:00  ...                  0.208278            0.146817
# 10682 2019-05-09 19:15:00  ...                  0.415313            0.004206
#
#        Mean_encoded_Airline  Mean_encoded_Source  Mean_encoded_Destination  \
# 0               5668.469897          8022.872877               8022.872877
# 1               9556.608028          9143.083566               9143.083566
# 2              11599.021081         10461.600690              10461.600690
# 3               5668.469897          9143.083566               9143.083566
# 4               5668.469897          8022.872877               8022.872877
# ...                     ...                  ...                       ...
# 10678           5590.260188          9143.083566               9143.083566
# 10679           9556.608028          9143.083566               9143.083566
# 10680          11599.021081          8022.872877               8022.872877
# 10681           7801.355649          8022.872877               8022.872877
# 10682           9556.608028         10461.600690              10461.600690
#
#        Mean_encoded_Route  Label_encoded_Airline  Label_encoded_Source  \
# 0             5552.235677                      3                     0
# 1             7369.166667                      1                     3
# 2            13277.195122                      4                     2
# 3             6279.333333                      3                     3
# 4            11313.000000                      3                     0
# ...                   ...                    ...                   ...
# 10678         4556.055249                      0                     3
# 10679         4556.055249                      1                     3
# 10680         5552.235677                      4                     0
# 10681         5552.235677                     10                     0
# 10682        11941.818182                      1                     2
#
#        Label_encoded_Destination  Label_encoded_Route
# 0                              2                   18
# 1                              0                   84
# 2                              1                  118
# 3                              0                   91
# 4                              2                   29
# ...                          ...                  ...
# 10678                          0                   64
# 10679                          0                   64
# 10680                          2                   18
# 10681                          2                   18
# 10682                          1                  108
#
# [10462 rows x 22 columns]

# %%
categorical_cols = ['Airline', 'Source', 'Destination', 'Route']
df.drop(columns=categorical_cols,inplace=True)

# %%
df.corr()
# Out:
#                            Total_Stops     Price  Duration_min  \
# Total_Stops                   1.000000  0.602013      0.727982
# Price                         0.602013  1.000000      0.501758
# Duration_min                  0.727982  0.501758      1.000000
# Freq_encoded_Airline          0.211803  0.371620      0.289457
# Freq_encoded_Source           0.571402  0.350997      0.400039
# Freq_encoded_Destination      0.571402  0.350997      0.400039
# Freq_encoded_Route           -0.205605  0.038912     -0.111065
# Mean_encoded_Airline          0.421327  0.638674      0.433989
# Mean_encoded_Source           0.559200  0.359938      0.414954
# Mean_encoded_Destination      0.559200  0.359938      0.414954
# Mean_encoded_Route            0.806690  0.746275      0.671871
# Label_encoded_Airline        -0.194549 -0.036491     -0.153618
# Label_encoded_Source          0.194203  0.013796      0.162808
# Label_encoded_Destination    -0.422656 -0.260751     -0.383773
# Label_encoded_Route           0.441347  0.154374      0.273200
#
#                            Freq_encoded_Airline  Freq_encoded_Source  \
# Total_Stops                            0.211803             0.571402
# Price                                  0.371620             0.350997
# Duration_min                           0.289457             0.400039
# Freq_encoded_Airline                   1.000000             0.038026
# Freq_encoded_Source                    0.038026             1.000000
# Freq_encoded_Destination               0.038026             1.000000
# Freq_encoded_Route                     0.019636             0.303115
# Mean_encoded_Airline                   0.581861             0.258498
# Mean_encoded_Source                    0.056089             0.975159
# Mean_encoded_Destination               0.056089             0.975159
# Mean_encoded_Route                     0.367567             0.470332
# Label_encoded_Airline                 -0.200348            -0.049748
# Label_encoded_Source                   0.055926             0.066914
# Label_encoded_Destination             -0.107401            -0.596026
# Label_encoded_Route                   -0.065789             0.612054
#
#                            Freq_encoded_Destination  Freq_encoded_Route  \
# Total_Stops                                0.571402           -0.205605
# Price                                      0.350997            0.038912
# Duration_min                               0.400039           -0.111065
# Freq_encoded_Airline                       0.038026            0.019636
# Freq_encoded_Source                        1.000000            0.303115
# Freq_encoded_Destination                   1.000000            0.303115
# Freq_encoded_Route                         0.303115            1.000000
# Mean_encoded_Airline                       0.258498            0.158467
# Mean_encoded_Source                        0.975159            0.272478
# Mean_encoded_Destination                   0.975159            0.272478
# Mean_encoded_Route                         0.470332            0.052142
# Label_encoded_Airline                     -0.049748            0.194054
# Label_encoded_Source                       0.066914           -0.196373
# Label_encoded_Destination                 -0.596026           -0.001272
# Label_encoded_Route                        0.612054            0.055678
#
#                            Mean_encoded_Airline  Mean_encoded_Source  \
# Total_Stops                            0.421327             0.559200
# Price                                  0.638674             0.359938
# Duration_min                           0.433989             0.414954
# Freq_encoded_Airline                   0.581861             0.056089
# Freq_encoded_Source                    0.258498             0.975159
# Freq_encoded_Destination               0.258498             0.975159
# Freq_encoded_Route                     0.158467             0.272478
# Mean_encoded_Airline                   1.000000             0.257259
# Mean_encoded_Source                    0.257259             1.000000
# Mean_encoded_Destination               0.257259             1.000000
# Mean_encoded_Route                     0.572144             0.482313
# Label_encoded_Airline                 -0.057135            -0.059864
# Label_encoded_Source                   0.047805             0.038329
# Label_encoded_Destination             -0.183451            -0.724431
# Label_encoded_Route                    0.071608             0.496810
#
#                            Mean_encoded_Destination  Mean_encoded_Route  \
# Total_Stops                                0.559200            0.806690
# Price                                      0.359938            0.746275
# Duration_min                               0.414954            0.671871
# Freq_encoded_Airline                       0.056089            0.367567
# Freq_encoded_Source                        0.975159            0.470332
# Freq_encoded_Destination                   0.975159            0.470332
# Freq_encoded_Route                         0.272478            0.052142
# Mean_encoded_Airline                       0.257259            0.572144
# Mean_encoded_Source                        1.000000            0.482313
# Mean_encoded_Destination                   1.000000            0.482313
# Mean_encoded_Route                         0.482313            1.000000
# Label_encoded_Airline                     -0.059864           -0.058168
# Label_encoded_Source                       0.038329            0.018486
# Label_encoded_Destination                 -0.724431           -0.349403
# Label_encoded_Route                        0.496810            0.206860
#
#                            Label_encoded_Airline  Label_encoded_Source  \
# Total_Stops                            -0.194549              0.194203
# Price                                  -0.036491              0.013796
# Duration_min                           -0.153618              0.162808
# Freq_encoded_Airline                   -0.200348              0.055926
# Freq_encoded_Source                    -0.049748              0.066914
# Freq_encoded_Destination               -0.049748              0.066914
# Freq_encoded_Route                      0.194054             -0.196373
# Mean_encoded_Airline                   -0.057135              0.047805
# Mean_encoded_Source                    -0.059864              0.038329
# Mean_encoded_Destination               -0.059864              0.038329
# Mean_encoded_Route                     -0.058168              0.018486
# Label_encoded_Airline                   1.000000             -0.012172
# Label_encoded_Source                   -0.012172              1.000000
# Label_encoded_Destination               0.068634             -0.432609
# Label_encoded_Route                     0.029636              0.403884
#
#                            Label_encoded_Destination  Label_encoded_Route
# Total_Stops                                -0.422656             0.441347
# Price                                      -0.260751             0.154374
# Duration_min                               -0.383773             0.273200
# Freq_encoded_Airline                       -0.107401            -0.065789
# Freq_encoded_Source                        -0.596026             0.612054
# Freq_encoded_Destination                   -0.596026             0.612054
# Freq_encoded_Route                         -0.001272             0.055678
# Mean_encoded_Airline                       -0.183451             0.071608
# Mean_encoded_Source                        -0.724431             0.496810
# Mean_encoded_Destination                   -0.724431             0.496810
# Mean_encoded_Route                         -0.349403             0.206860
# Label_encoded_Airline                       0.068634             0.029636
# Label_encoded_Source                       -0.432609             0.403884
# Label_encoded_Destination                   1.000000            -0.229487
# Label_encoded_Route                        -0.229487             1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import SplineTransformer

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor


def regression(X_train, X_test, y_train, y_test):
    ## Baseline model
    reg = linear_model.LinearRegression()
    reg.fit(X_train,y_train)
    print(metrics.r2_score(y_train,reg.predict(X_train)), metrics.r2_score(y_test,reg.predict(X_test)))
    return reg

def knearestneighbour(X_train, X_test, y_train, y_test):
    k_range = list(range(1, 30))
    params = dict(n_neighbors = k_range)
    knn_regressor = GridSearchCV(KNeighborsRegressor(), params, cv =10, scoring = 'neg_mean_squared_error')
    knn_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,knn_regressor.predict(X_train)),metrics.r2_score(y_test,knn_regressor.predict(X_test)))
    return knn_regressor

def decisiontree(X_train, X_test, y_train, y_test):
    depth  =list(range(3,30))
    param_grid =dict(max_depth =depth)
    tree =GridSearchCV(DecisionTreeRegressor(),param_grid,cv =10)
    tree.fit(X_train,y_train)
    print(metrics.r2_score(y_train,tree.predict(X_train)),metrics.r2_score(y_test,tree.predict(X_test)))
    return tree

def randomForest(X_train, X_test, y_train, y_test):
    random_regressor = RandomForestRegressor(n_estimators=500, min_samples_split=10,min_samples_leaf=2)
    random_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,random_regressor.predict(X_train)),metrics.r2_score(y_test,random_regressor.predict(X_test)))
    return random_regressor

from xgboost import XGBRegressor
def xgboost(X_train, X_test, y_train, y_test):
    xgboost_regressor = XGBRegressor()
    xgboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
    return xgboost_regressor

from catboost import  CatBoostRegressor
def catboost(X_train, X_test, y_train, y_test):
    catboost_regressor = CatBoostRegressor(verbose=False)
    catboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,catboost_regressor.predict(X_train)),metrics.r2_score(y_test,catboost_regressor.predict(X_test)))
    return catboost_regressor

from sklearn.ensemble import GradientBoostingRegressor
def gboost(X_train, X_test, y_train, y_test):
    gboost_regressor = GradientBoostingRegressor()
    gboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,gboost_regressor.predict(X_train)),metrics.r2_score(y_test,gboost_regressor.predict(X_test)))
    return gboost_regressor


def train(X,y,modelType):
    # Split your dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    model = modelType(X_train, X_test, y_train, y_test)
    return model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']

model = train(X,y,regression)
model = train(X,y,knearestneighbour)
model = train(X,y,decisiontree)
model = train(X,y,randomForest)
# Out:
# 0.7358081967243686 0.6427661709912476

# %%
from sklearn.linear_model import LinearRegression
def sklearn_vif(exogs, data):
    '''
    This function calculates variance inflation function in sklearn way. 
     It is a comparatively faster process.

    '''
    # initialize dictionaries
    vif_dict, tolerance_dict = {}, {}

    # form input data for each exogenous variable
    for exog in exogs:
        not_exog = [i for i in exogs if i != exog]
        X, y = data[not_exog], data[exog]

        # extract r-squared from the fit
        r_squared = LinearRegression().fit(X, y).score(X, y)

        # calculate VIF
        vif = 1/(1 - r_squared)
        vif_dict[exog] = vif

        # calculate tolerance
        tolerance = 1 - r_squared
        tolerance_dict[exog] = tolerance

    # return VIF DataFrame
    df_vif = pd.DataFrame({'VIF': vif_dict, 'Tolerance': tolerance_dict})

    return df_vif

df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)
# Out:
# C:\Users\theve\AppData\Local\Temp/ipykernel_49688/2747831194.py:20: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1/(1 - r_squared)
# C:\Users\theve\AppData\Local\Temp/ipykernel_49688/2747831194.py:20: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1/(1 - r_squared)
# C:\Users\theve\AppData\Local\Temp/ipykernel_49688/2747831194.py:20: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1/(1 - r_squared)
# C:\Users\theve\AppData\Local\Temp/ipykernel_49688/2747831194.py:20: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1/(1 - r_squared)

# %%
df_vif
# Out:
#                                     VIF  Tolerance
# Freq_encoded_Source                 inf   0.000000
# Freq_encoded_Destination            inf   0.000000
# Mean_encoded_Source                 inf   0.000000
# Mean_encoded_Destination            inf   0.000000
# Label_encoded_Destination  6.549515e+04   0.000015
# Label_encoded_Source       1.463039e+04   0.000068
# Label_encoded_Route        5.382753e+01   0.018578
# Total_Stops                8.105551e+00   0.123372
# Mean_encoded_Route         6.025714e+00   0.165955
# Duration_min               2.349205e+00   0.425676
# Mean_encoded_Airline       2.073474e+00   0.482282
# Freq_encoded_Route         1.943690e+00   0.514485
# Freq_encoded_Airline       1.707186e+00   0.585759
# Label_encoded_Airline      1.201918e+00   0.832004

# %%
source_cols = [col for col in df.columns if 'Source' in col]
df.drop(columns=source_cols,inplace=True)
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']

model = train(X,y,randomForest)
# Out:
# 0.7358139187092697 0.6421800221351759

# %%
df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)

# %%
df_vif
# Out:
#                                   VIF  Tolerance
# Mean_encoded_Destination   114.774637   0.008713
# Freq_encoded_Destination   104.782932   0.009544
# Total_Stops                  6.926954   0.144364
# Label_encoded_Destination    6.243716   0.160161
# Mean_encoded_Route           4.833028   0.206910
# Label_encoded_Route          3.537661   0.282673
# Duration_min                 2.348953   0.425722
# Mean_encoded_Airline         2.072776   0.482445
# Freq_encoded_Route           1.940748   0.515265
# Freq_encoded_Airline         1.704573   0.586657
# Label_encoded_Airline        1.191287   0.839428

# %%
df.drop(columns=['Mean_encoded_Destination'],inplace=True)

# %%
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']


model = train(X,y,randomForest)
# Out:
# 0.7352454856335787 0.6410742575482115

# %%
df_vif= sklearn_vif(exogs=X.columns, data=df).sort_values(by='VIF',ascending=False)
df_vif
# Out:
#                                 VIF  Tolerance
# Total_Stops                6.820147   0.146624
# Mean_encoded_Route         4.747217   0.210650
# Freq_encoded_Destination   3.927580   0.254610
# Duration_min               2.344562   0.426519
# Mean_encoded_Airline       2.051917   0.487349
# Label_encoded_Route        2.029337   0.492772
# Freq_encoded_Route         1.928397   0.518565
# Label_encoded_Destination  1.830819   0.546204
# Freq_encoded_Airline       1.701212   0.587816
# Label_encoded_Airline      1.191270   0.839440

# %%
from sklearn.preprocessing import RobustScaler

X_transform = RobustScaler().fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)
model = train(X_transformed,y,randomForest)
# Out:
# 0.7359258872320176 0.64329758796121

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                            Total_Stops  Duration_min  Freq_encoded_Airline  \
# Total_Stops                   1.000000      0.727982              0.211803
# Duration_min                  0.727982      1.000000              0.289457
# Freq_encoded_Airline          0.211803      0.289457              1.000000
# Freq_encoded_Destination      0.571402      0.400039              0.038026
# Freq_encoded_Route           -0.205605     -0.111065              0.019636
# Mean_encoded_Airline          0.421327      0.433989              0.581861
# Mean_encoded_Route            0.806690      0.671871              0.367567
# Label_encoded_Airline        -0.194549     -0.153618             -0.200348
# Label_encoded_Destination    -0.422656     -0.383773             -0.107401
# Label_encoded_Route           0.441347      0.273200             -0.065789
# Price                         0.039017      0.027030              0.006926
#
#                            Freq_encoded_Destination  Freq_encoded_Route  \
# Total_Stops                                0.571402           -0.205605
# Duration_min                               0.400039           -0.111065
# Freq_encoded_Airline                       0.038026            0.019636
# Freq_encoded_Destination                   1.000000            0.303115
# Freq_encoded_Route                         0.303115            1.000000
# Mean_encoded_Airline                       0.258498            0.158467
# Mean_encoded_Route                         0.470332            0.052142
# Label_encoded_Airline                     -0.049748            0.194054
# Label_encoded_Destination                 -0.596026           -0.001272
# Label_encoded_Route                        0.612054            0.055678
# Price                                      0.039077            0.027073
#
#                            Mean_encoded_Airline  Mean_encoded_Route  \
# Total_Stops                            0.421327            0.806690
# Duration_min                           0.433989            0.671871
# Freq_encoded_Airline                   0.581861            0.367567
# Freq_encoded_Destination               0.258498            0.470332
# Freq_encoded_Route                     0.158467            0.052142
# Mean_encoded_Airline                   1.000000            0.572144
# Mean_encoded_Route                     0.572144            1.000000
# Label_encoded_Airline                 -0.057135           -0.058168
# Label_encoded_Destination             -0.183451           -0.349403
# Label_encoded_Route                    0.071608            0.206860
# Price                                  0.049989            0.054850
#
#                            Label_encoded_Airline  Label_encoded_Destination  \
# Total_Stops                            -0.194549                  -0.422656
# Duration_min                           -0.153618                  -0.383773
# Freq_encoded_Airline                   -0.200348                  -0.107401
# Freq_encoded_Destination               -0.049748                  -0.596026
# Freq_encoded_Route                      0.194054                  -0.001272
# Mean_encoded_Airline                   -0.057135                  -0.183451
# Mean_encoded_Route                     -0.058168                  -0.349403
# Label_encoded_Airline                   1.000000                   0.068634
# Label_encoded_Destination               0.068634                   1.000000
# Label_encoded_Route                     0.029636                  -0.229487
# Price                                   0.011536                  -0.023831
#
#                            Label_encoded_Route     Price
# Total_Stops                           0.441347  0.039017
# Duration_min                          0.273200  0.027030
# Freq_encoded_Airline                 -0.065789  0.006926
# Freq_encoded_Destination              0.612054  0.039077
# Freq_encoded_Route                    0.055678  0.027073
# Mean_encoded_Airline                  0.071608  0.049989
# Mean_encoded_Route                    0.206860  0.054850
# Label_encoded_Airline                 0.029636  0.011536
# Label_encoded_Destination            -0.229487 -0.023831
# Label_encoded_Route                   1.000000  0.014320
# Price                                 0.014320  1.000000

# %%
from sklearn.preprocessing import PowerTransformer

X_transform = PowerTransformer().fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)
model = train(X_transformed,y,randomForest)
# Out:
# 0.7359361327495915 0.6427934627158465

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                            Total_Stops  Duration_min  Freq_encoded_Airline  \
# Total_Stops                   1.000000      0.844850              0.226303
# Duration_min                  0.844850      1.000000              0.291936
# Freq_encoded_Airline          0.226303      0.291936              1.000000
# Freq_encoded_Destination      0.594835      0.535225              0.025808
# Freq_encoded_Route           -0.257056     -0.086790              0.029916
# Mean_encoded_Airline          0.466701      0.524692              0.600581
# Mean_encoded_Route            0.844533      0.819401              0.355888
# Label_encoded_Airline        -0.154681     -0.108921             -0.081844
# Label_encoded_Destination    -0.373699     -0.425656             -0.097448
# Label_encoded_Route           0.458192      0.352314             -0.060665
# Price                         0.039913      0.036260              0.006537
#
#                            Freq_encoded_Destination  Freq_encoded_Route  \
# Total_Stops                                0.594835           -0.257056
# Duration_min                               0.535225           -0.086790
# Freq_encoded_Airline                       0.025808            0.029916
# Freq_encoded_Destination                   1.000000            0.215073
# Freq_encoded_Route                         0.215073            1.000000
# Mean_encoded_Airline                       0.267096            0.140361
# Mean_encoded_Route                         0.490481            0.009358
# Label_encoded_Airline                     -0.015420            0.251402
# Label_encoded_Destination                 -0.328968            0.087376
# Label_encoded_Route                        0.687665           -0.032610
# Price                                      0.038186            0.022537
#
#                            Mean_encoded_Airline  Mean_encoded_Route  \
# Total_Stops                            0.466701            0.844533
# Duration_min                           0.524692            0.819401
# Freq_encoded_Airline                   0.600581            0.355888
# Freq_encoded_Destination               0.267096            0.490481
# Freq_encoded_Route                     0.140361            0.009358
# Mean_encoded_Airline                   1.000000            0.601058
# Mean_encoded_Route                     0.601058            1.000000
# Label_encoded_Airline                 -0.014827           -0.017892
# Label_encoded_Destination             -0.139421           -0.296602
# Label_encoded_Route                    0.081027            0.239712
# Price                                  0.045154            0.054375
#
#                            Label_encoded_Airline  Label_encoded_Destination  \
# Total_Stops                            -0.154681                  -0.373699
# Duration_min                           -0.108921                  -0.425656
# Freq_encoded_Airline                   -0.081844                  -0.097448
# Freq_encoded_Destination               -0.015420                  -0.328968
# Freq_encoded_Route                      0.251402                   0.087376
# Mean_encoded_Airline                   -0.014827                  -0.139421
# Mean_encoded_Route                     -0.017892                  -0.296602
# Label_encoded_Airline                   1.000000                   0.054979
# Label_encoded_Destination               0.054979                   1.000000
# Label_encoded_Route                     0.042487                  -0.191226
# Price                                   0.013280                  -0.015926
#
#                            Label_encoded_Route     Price
# Total_Stops                           0.458192  0.039913
# Duration_min                          0.352314  0.036260
# Freq_encoded_Airline                 -0.060665  0.006537
# Freq_encoded_Destination              0.687665  0.038186
# Freq_encoded_Route                   -0.032610  0.022537
# Mean_encoded_Airline                  0.081027  0.045154
# Mean_encoded_Route                    0.239712  0.054375
# Label_encoded_Airline                 0.042487  0.013280
# Label_encoded_Destination            -0.191226 -0.015926
# Label_encoded_Route                   1.000000  0.014430
# Price                                 0.014430  1.000000

# %%
from sklearn.preprocessing import FunctionTransformer

X_transform = FunctionTransformer(np.log1p).fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)
model = train(X_transformed,y,randomForest)
# Out:
# 0.7355071639662074 0.6425290563066923

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                            Total_Stops  Duration_min  Freq_encoded_Airline  \
# Total_Stops                   1.000000      0.863786              0.232432
# Duration_min                  0.863786      1.000000              0.288951
# Freq_encoded_Airline          0.232432      0.288951              1.000000
# Freq_encoded_Destination      0.615532      0.584356              0.044400
# Freq_encoded_Route           -0.146651     -0.018656              0.019247
# Mean_encoded_Airline          0.490239      0.544532              0.601074
# Mean_encoded_Route            0.867788      0.850498              0.342026
# Label_encoded_Airline        -0.115757     -0.084262              0.035451
# Label_encoded_Destination    -0.378406     -0.425020             -0.096738
# Label_encoded_Route           0.368466      0.273478             -0.076925
# Price                         0.626180      0.601974              0.366855
#
#                            Freq_encoded_Destination  Freq_encoded_Route  \
# Total_Stops                                0.615532           -0.146651
# Duration_min                               0.584356           -0.018656
# Freq_encoded_Airline                       0.044400            0.019247
# Freq_encoded_Destination                   1.000000            0.284566
# Freq_encoded_Route                         0.284566            1.000000
# Mean_encoded_Airline                       0.289999            0.163356
# Mean_encoded_Route                         0.563480            0.096027
# Label_encoded_Airline                     -0.016786            0.257797
# Label_encoded_Destination                 -0.431073            0.101184
# Label_encoded_Route                        0.502693            0.048743
# Price                                      0.354439            0.029534
#
#                            Mean_encoded_Airline  Mean_encoded_Route  \
# Total_Stops                            0.490239            0.867788
# Duration_min                           0.544532            0.850498
# Freq_encoded_Airline                   0.601074            0.342026
# Freq_encoded_Destination               0.289999            0.563480
# Freq_encoded_Route                     0.163356            0.096027
# Mean_encoded_Airline                   1.000000            0.609313
# Mean_encoded_Route                     0.609313            1.000000
# Label_encoded_Airline                  0.004491            0.013449
# Label_encoded_Destination             -0.137142           -0.312079
# Label_encoded_Route                    0.040957            0.137305
# Price                                  0.610871            0.734900
#
#                            Label_encoded_Airline  Label_encoded_Destination  \
# Total_Stops                            -0.115757                  -0.378406
# Duration_min                           -0.084262                  -0.425020
# Freq_encoded_Airline                    0.035451                  -0.096738
# Freq_encoded_Destination               -0.016786                  -0.431073
# Freq_encoded_Route                      0.257797                   0.101184
# Mean_encoded_Airline                    0.004491                  -0.137142
# Mean_encoded_Route                      0.013449                  -0.312079
# Label_encoded_Airline                   1.000000                   0.057037
# Label_encoded_Destination               0.057037                   1.000000
# Label_encoded_Route                     0.030229                  -0.341735
# Price                                   0.034959                  -0.195564
#
#                            Label_encoded_Route     Price
# Total_Stops                           0.368466  0.626180
# Duration_min                          0.273478  0.601974
# Freq_encoded_Airline                 -0.076925  0.366855
# Freq_encoded_Destination              0.502693  0.354439
# Freq_encoded_Route                    0.048743  0.029534
# Mean_encoded_Airline                  0.040957  0.610871
# Mean_encoded_Route                    0.137305  0.734900
# Label_encoded_Airline                 0.030229  0.034959
# Label_encoded_Destination            -0.341735 -0.195564
# Label_encoded_Route                   1.000000  0.054002
# Price                                 0.054002  1.000000

# %%
from sklearn.preprocessing import FunctionTransformer
def cube(X): return X**(0.333)

X_transform = FunctionTransformer(cube).fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)
model = train(X_transformed,y,randomForest)
# Out:
# 0.7359923869936025 0.6435427276039772

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                            Total_Stops  Duration_min  Freq_encoded_Airline  \
# Total_Stops                   1.000000      0.833065              0.239045
# Duration_min                  0.833065      1.000000              0.286370
# Freq_encoded_Airline          0.239045      0.286370              1.000000
# Freq_encoded_Destination      0.621873      0.526672              0.063097
# Freq_encoded_Route           -0.232358     -0.176549              0.027772
# Mean_encoded_Airline          0.495621      0.527382              0.562445
# Mean_encoded_Route            0.873024      0.799758              0.328025
# Label_encoded_Airline        -0.043271     -0.067232              0.077002
# Label_encoded_Destination    -0.273600     -0.294052             -0.072750
# Label_encoded_Route           0.420080      0.297467             -0.035205
# Price                         0.628457      0.576777              0.333373
#
#                            Freq_encoded_Destination  Freq_encoded_Route  \
# Total_Stops                                0.621873           -0.232358
# Duration_min                               0.526672           -0.176549
# Freq_encoded_Airline                       0.063097            0.027772
# Freq_encoded_Destination                   1.000000            0.142225
# Freq_encoded_Route                         0.142225            1.000000
# Mean_encoded_Airline                       0.290668            0.107632
# Mean_encoded_Route                         0.541300           -0.058498
# Label_encoded_Airline                     -0.036344            0.261455
# Label_encoded_Destination                 -0.286197            0.135966
# Label_encoded_Route                        0.418825           -0.040536
# Price                                      0.358264           -0.067720
#
#                            Mean_encoded_Airline  Mean_encoded_Route  \
# Total_Stops                            0.495621            0.873024
# Duration_min                           0.527382            0.799758
# Freq_encoded_Airline                   0.562445            0.328025
# Freq_encoded_Destination               0.290668            0.541300
# Freq_encoded_Route                     0.107632           -0.058498
# Mean_encoded_Airline                   1.000000            0.607769
# Mean_encoded_Route                     0.607769            1.000000
# Label_encoded_Airline                  0.059308            0.034782
# Label_encoded_Destination             -0.069334           -0.182592
# Label_encoded_Route                    0.060645            0.175625
# Price                                  0.621726            0.740985
#
#                            Label_encoded_Airline  Label_encoded_Destination  \
# Total_Stops                            -0.043271                  -0.273600
# Duration_min                           -0.067232                  -0.294052
# Freq_encoded_Airline                    0.077002                  -0.072750
# Freq_encoded_Destination               -0.036344                  -0.286197
# Freq_encoded_Route                      0.261455                   0.135966
# Mean_encoded_Airline                    0.059308                  -0.069334
# Mean_encoded_Route                      0.034782                  -0.182592
# Label_encoded_Airline                   1.000000                   0.065459
# Label_encoded_Destination               0.065459                   1.000000
# Label_encoded_Route                     0.039893                  -0.200193
# Price                                   0.054084                  -0.118911
#
#                            Label_encoded_Route     Price
# Total_Stops                           0.420080  0.628457
# Duration_min                          0.297467  0.576777
# Freq_encoded_Airline                 -0.035205  0.333373
# Freq_encoded_Destination              0.418825  0.358264
# Freq_encoded_Route                   -0.040536 -0.067720
# Mean_encoded_Airline                  0.060645  0.621726
# Mean_encoded_Route                    0.175625  0.740985
# Label_encoded_Airline                 0.039893  0.054084
# Label_encoded_Destination            -0.200193 -0.118911
# Label_encoded_Route                   1.000000  0.097279
# Price                                 0.097279  1.000000

# %%
model = train(X,y,xgboost)
model = train(X,y,catboost)
model = train(X,y,gboost)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.751058049628192 0.6296232654999112
# 0.7292652918747647 0.6476710811482218
# 0.6835326145533955 0.6477316538436303

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=False,interaction_only=False)

# %%
X_transform = poly.fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=poly.get_feature_names(X.columns))
model = train(X_transformed,y,randomForest)
model = train(X_transformed,y,xgboost)
model = train(X_transformed,y,catboost)
model = train(X_transformed,y,gboost)
# Out:
# C:\Users\theve\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 0.7419392855826143 0.642883564490212
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.7558889585669635 0.6192899099734246
# 0.7414142539971079 0.6437212606732532
# 0.7041741158282632 0.6511120877019569

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                                                  Total_Stops  Duration_min  \
# Total_Stops                                         1.000000      0.727982
# Duration_min                                        0.727982      1.000000
# Freq_encoded_Airline                                0.211803      0.289457
# Freq_encoded_Destination                            0.571402      0.400039
# Freq_encoded_Route                                 -0.205605     -0.111065
# ...                                                      ...           ...
# Label_encoded_Destination^3                        -0.420359     -0.346999
# Label_encoded_Destination^2 Label_encoded_Route    -0.275403     -0.242886
# Label_encoded_Destination Label_encoded_Route^2    -0.050335     -0.095936
# Label_encoded_Route^3                               0.378800      0.204657
# Price                                               0.039017      0.027030
#
#                                                  Freq_encoded_Airline  \
# Total_Stops                                                  0.211803
# Duration_min                                                 0.289457
# Freq_encoded_Airline                                         1.000000
# Freq_encoded_Destination                                     0.038026
# Freq_encoded_Route                                           0.019636
# ...                                                               ...
# Label_encoded_Destination^3                                 -0.118523
# Label_encoded_Destination^2 Label_encoded_Route             -0.137826
# Label_encoded_Destination Label_encoded_Route^2             -0.136830
# Label_encoded_Route^3                                       -0.088243
# Price                                                        0.006926
#
#                                                  Freq_encoded_Destination  \
# Total_Stops                                                      0.571402
# Duration_min                                                     0.400039
# Freq_encoded_Airline                                             0.038026
# Freq_encoded_Destination                                         1.000000
# Freq_encoded_Route                                               0.303115
# ...                                                                   ...
# Label_encoded_Destination^3                                     -0.727703
# Label_encoded_Destination^2 Label_encoded_Route                 -0.491623
# Label_encoded_Destination Label_encoded_Route^2                 -0.112207
# Label_encoded_Route^3                                            0.530381
# Price                                                            0.039077
#
#                                                  Freq_encoded_Route  \
# Total_Stops                                               -0.205605
# Duration_min                                              -0.111065
# Freq_encoded_Airline                                       0.019636
# Freq_encoded_Destination                                   0.303115
# Freq_encoded_Route                                         1.000000
# ...                                                             ...
# Label_encoded_Destination^3                               -0.181197
# Label_encoded_Destination^2 Label_encoded_Route           -0.140140
# Label_encoded_Destination Label_encoded_Route^2           -0.042618
# Label_encoded_Route^3                                      0.041758
# Price                                                      0.027073
#
#                                                  Mean_encoded_Airline  \
# Total_Stops                                                  0.421327
# Duration_min                                                 0.433989
# Freq_encoded_Airline                                         0.581861
# Freq_encoded_Destination                                     0.258498
# Freq_encoded_Route                                           0.158467
# ...                                                               ...
# Label_encoded_Destination^3                                 -0.251697
# Label_encoded_Destination^2 Label_encoded_Route             -0.226060
# Label_encoded_Destination Label_encoded_Route^2             -0.141272
# Label_encoded_Route^3                                        0.034242
# Price                                                        0.049989
#
#                                                  Mean_encoded_Route  \
# Total_Stops                                                0.806690
# Duration_min                                               0.671871
# Freq_encoded_Airline                                       0.367567
# Freq_encoded_Destination                                   0.470332
# Freq_encoded_Route                                         0.052142
# ...                                                             ...
# Label_encoded_Destination^3                               -0.398576
# Label_encoded_Destination^2 Label_encoded_Route           -0.303257
# Label_encoded_Destination Label_encoded_Route^2           -0.129033
# Label_encoded_Route^3                                      0.180877
# Price                                                      0.054850
#
#                                                  Label_encoded_Airline  \
# Total_Stops                                                  -0.194549
# Duration_min                                                 -0.153618
# Freq_encoded_Airline                                         -0.200348
# Freq_encoded_Destination                                     -0.049748
# Freq_encoded_Route                                            0.194054
# ...                                                                ...
# Label_encoded_Destination^3                                   0.102102
# Label_encoded_Destination^2 Label_encoded_Route               0.112474
# Label_encoded_Destination Label_encoded_Route^2               0.102435
# Label_encoded_Route^3                                         0.039572
# Price                                                         0.011536
#
#                                                  Label_encoded_Destination  \
# Total_Stops                                                      -0.422656
# Duration_min                                                     -0.383773
# Freq_encoded_Airline                                             -0.107401
# Freq_encoded_Destination                                         -0.596026
# Freq_encoded_Route                                               -0.001272
# ...                                                                    ...
# Label_encoded_Destination^3                                       0.830037
# Label_encoded_Destination^2 Label_encoded_Route                   0.683151
# Label_encoded_Destination Label_encoded_Route^2                   0.534772
# Label_encoded_Route^3                                             0.039310
# Price                                                            -0.023831
#
#                                                  Label_encoded_Route  ...  \
# Total_Stops                                                 0.441347  ...
# Duration_min                                                0.273200  ...
# Freq_encoded_Airline                                       -0.065789  ...
# Freq_encoded_Destination                                    0.612054  ...
# Freq_encoded_Route                                          0.055678  ...
# ...                                                              ...  ...
# Label_encoded_Destination^3                                -0.019315  ...
# Label_encoded_Destination^2 Label_encoded_Route             0.278695  ...
# Label_encoded_Destination Label_encoded_Route^2             0.582525  ...
# Label_encoded_Route^3                                       0.926228  ...
# Price                                                       0.014320  ...
#
#                                                  Label_encoded_Airline^2 Label_encoded_Destination  \
# Total_Stops                                                                              -0.306584
# Duration_min                                                                             -0.270878
# Freq_encoded_Airline                                                                     -0.303175
# Freq_encoded_Destination                                                                 -0.371225
# Freq_encoded_Route                                                                        0.026109
# ...                                                                                            ...
# Label_encoded_Destination^3                                                               0.548979
# Label_encoded_Destination^2 Label_encoded_Route                                           0.504613
# Label_encoded_Destination Label_encoded_Route^2                                           0.415974
# Label_encoded_Route^3                                                                     0.089562
# Price                                                                                    -0.006297
#
#                                                  Label_encoded_Airline^2 Label_encoded_Route  \
# Total_Stops                                                                        -0.028720
# Duration_min                                                                       -0.058625
# Freq_encoded_Airline                                                               -0.358508
# Freq_encoded_Destination                                                            0.105170
# Freq_encoded_Route                                                                  0.099583
# ...                                                                                      ...
# Label_encoded_Destination^3                                                         0.175362
# Label_encoded_Destination^2 Label_encoded_Route                                     0.299319
# Label_encoded_Destination Label_encoded_Route^2                                     0.380749
# Label_encoded_Route^3                                                               0.391467
# Price                                                                               0.004221
#
#                                                  Label_encoded_Airline Label_encoded_Destination^2  \
# Total_Stops                                                                              -0.385577
# Duration_min                                                                             -0.321736
# Freq_encoded_Airline                                                                     -0.191894
# Freq_encoded_Destination                                                                 -0.594323
# Freq_encoded_Route                                                                       -0.095006
# ...                                                                                            ...
# Label_encoded_Destination^3                                                               0.824066
# Label_encoded_Destination^2 Label_encoded_Route                                           0.766083
# Label_encoded_Destination Label_encoded_Route^2                                           0.612491
# Label_encoded_Route^3                                                                     0.118689
# Price                                                                                    -0.021100
#
#                                                  Label_encoded_Airline Label_encoded_Destination Label_encoded_Route  \
# Total_Stops                                                                              -0.164184
# Duration_min                                                                             -0.190698
# Freq_encoded_Airline                                                                     -0.207421
# Freq_encoded_Destination                                                                 -0.227965
# Freq_encoded_Route                                                                        0.021287
# ...                                                                                            ...
# Label_encoded_Destination^3                                                               0.712434
# Label_encoded_Destination^2 Label_encoded_Route                                           0.807238
# Label_encoded_Destination Label_encoded_Route^2                                           0.818663
# Label_encoded_Route^3                                                                     0.520478
# Price                                                                                    -0.012895
#
#                                                  Label_encoded_Airline Label_encoded_Route^2  \
# Total_Stops                                                                         0.165896
# Duration_min                                                                        0.041844
# Freq_encoded_Airline                                                               -0.176365
# Freq_encoded_Destination                                                            0.340714
# Freq_encoded_Route                                                                  0.175755
# ...                                                                                      ...
# Label_encoded_Destination^3                                                         0.178680
# Label_encoded_Destination^2 Label_encoded_Route                                     0.398223
# Label_encoded_Destination Label_encoded_Route^2                                     0.604022
# Label_encoded_Route^3                                                               0.730249
# Price                                                                               0.009156
#
#                                                  Label_encoded_Destination^3  \
# Total_Stops                                                        -0.420359
# Duration_min                                                       -0.346999
# Freq_encoded_Airline                                               -0.118523
# Freq_encoded_Destination                                           -0.727703
# Freq_encoded_Route                                                 -0.181197
# ...                                                                      ...
# Label_encoded_Destination^3                                         1.000000
# Label_encoded_Destination^2 Label_encoded_Route                     0.938533
# Label_encoded_Destination Label_encoded_Route^2                     0.747125
# Label_encoded_Route^3                                               0.154413
# Price                                                              -0.033157
#
#                                                  Label_encoded_Destination^2 Label_encoded_Route  \
# Total_Stops                                                                            -0.275403
# Duration_min                                                                           -0.242886
# Freq_encoded_Airline                                                                   -0.137826
# Freq_encoded_Destination                                                               -0.491623
# Freq_encoded_Route                                                                     -0.140140
# ...                                                                                          ...
# Label_encoded_Destination^3                                                             0.938533
# Label_encoded_Destination^2 Label_encoded_Route                                         1.000000
# Label_encoded_Destination Label_encoded_Route^2                                         0.918189
# Label_encoded_Route^3                                                                   0.438423
# Price                                                                                  -0.027101
#
#                                                  Label_encoded_Destination Label_encoded_Route^2  \
# Total_Stops                                                                            -0.050335
# Duration_min                                                                           -0.095936
# Freq_encoded_Airline                                                                   -0.136830
# Freq_encoded_Destination                                                               -0.112207
# Freq_encoded_Route                                                                     -0.042618
# ...                                                                                          ...
# Label_encoded_Destination^3                                                             0.747125
# Label_encoded_Destination^2 Label_encoded_Route                                         0.918189
# Label_encoded_Destination Label_encoded_Route^2                                         1.000000
# Label_encoded_Route^3                                                                   0.747939
# Price                                                                                  -0.013679
#
#                                                  Label_encoded_Route^3  \
# Total_Stops                                                   0.378800
# Duration_min                                                  0.204657
# Freq_encoded_Airline                                         -0.088243
# Freq_encoded_Destination                                      0.530381
# Freq_encoded_Route                                            0.041758
# ...                                                                ...
# Label_encoded_Destination^3                                   0.154413
# Label_encoded_Destination^2 Label_encoded_Route               0.438423
# Label_encoded_Destination Label_encoded_Route^2               0.747939
# Label_encoded_Route^3                                         1.000000
# Price                                                         0.010063
#
#                                                     Price
# Total_Stops                                      0.039017
# Duration_min                                     0.027030
# Freq_encoded_Airline                             0.006926
# Freq_encoded_Destination                         0.039077
# Freq_encoded_Route                               0.027073
# ...                                                   ...
# Label_encoded_Destination^3                     -0.033157
# Label_encoded_Destination^2 Label_encoded_Route -0.027101
# Label_encoded_Destination Label_encoded_Route^2 -0.013679
# Label_encoded_Route^3                            0.010063
# Price                                            1.000000
#
# [286 rows x 286 columns]

# %% [markdown]
# ## Adding Basic Time based Features

# %% [markdown]
# ## I

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night

df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

# %%
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']

# %%
print(X.columns)
# Out:
# Index(['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
#        'Freq_encoded_Destination', 'Freq_encoded_Route',
#        'Mean_encoded_Airline', 'Mean_encoded_Route', 'Label_encoded_Airline',
#        'Label_encoded_Destination', 'Label_encoded_Route', 'dep_hr', 'arr_hr',
#        'departure_timeOfDay_encoded', 'arrival_timeOfDay_encoded'],
#       dtype='object')

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.768463134747003 0.6395991503325551
#               feature_names_in_  feature_importances_
# 6            Mean_encoded_Route              0.663305
# 5          Mean_encoded_Airline              0.101672
# 1                  Duration_min              0.090357
# 2          Freq_encoded_Airline              0.044746
# 10                       dep_hr              0.029401
# 11                       arr_hr              0.028391
# 13    arrival_timeOfDay_encoded              0.010197
# 12  departure_timeOfDay_encoded              0.008716
# 4            Freq_encoded_Route              0.008190
# 7         Label_encoded_Airline              0.005660
# 9           Label_encoded_Route              0.005530
# 8     Label_encoded_Destination              0.001432
# 3      Freq_encoded_Destination              0.001360
# 0                   Total_Stops              0.001044

# %%
model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.705095614798555 0.6413969655216982
#               feature_names_in_  feature_importances_
# 6            Mean_encoded_Route              0.736141
# 5          Mean_encoded_Airline              0.154027
# 1                  Duration_min              0.036060
# 2          Freq_encoded_Airline              0.021127
# 11                       arr_hr              0.017447
# 10                       dep_hr              0.009583
# 13    arrival_timeOfDay_encoded              0.008631
# 4            Freq_encoded_Route              0.007773
# 9           Label_encoded_Route              0.002667
# 12  departure_timeOfDay_encoded              0.002506
# 7         Label_encoded_Airline              0.002290
# 8     Label_encoded_Destination              0.001618
# 0                   Total_Stops              0.000067
# 3      Freq_encoded_Destination              0.000063

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')
pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# 0.7911739598784131 0.6131836750453157
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                              weight         gain    total_gain        cover  \
# Total_Stops                   117.0    6927044.5  8.104642e+08   141.376068
# Duration_min                 1665.0   11333157.0  1.886971e+10  1188.499756
# Freq_encoded_Airline          245.0   81285944.0  1.991506e+10   896.469360
# Freq_encoded_Destination       73.0    4434839.0  3.237433e+08   311.273987
# Freq_encoded_Route            258.0    8981222.0  2.317155e+09  1076.844971
# Mean_encoded_Airline           98.0  138152528.0  1.353895e+10  1650.408203
# Mean_encoded_Route            219.0  720710848.0  1.578357e+11  1603.077637
# Label_encoded_Airline          62.0   13192606.0  8.179416e+08  1307.774170
# Label_encoded_Destination      23.0    6634640.5  1.525967e+08  1085.086914
# Label_encoded_Route           144.0    7092760.5  1.021358e+09  1271.423584
# dep_hr                        503.0   11907319.0  5.989382e+09   936.695801
# arr_hr                        345.0   14900769.0  5.140765e+09   909.194214
# departure_timeOfDay_encoded    33.0    8677246.0  2.863491e+08  1191.969727
# arrival_timeOfDay_encoded      66.0   17956372.0  1.185121e+09   797.272705
#
#                              total_cover
# Total_Stops                      16541.0
# Duration_min                   1978852.0
# Freq_encoded_Airline            219635.0
# Freq_encoded_Destination         22723.0
# Freq_encoded_Route              277826.0
# Mean_encoded_Airline            161740.0
# Mean_encoded_Route              351074.0
# Label_encoded_Airline            81082.0
# Label_encoded_Destination        24957.0
# Label_encoded_Route             183085.0
# dep_hr                          471158.0
# arr_hr                          313672.0
# departure_timeOfDay_encoded      39335.0
# arrival_timeOfDay_encoded        52620.0

# %%
model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7671194384975737 0.6388525719291527
#               feature_names_in_  feature_importances_
# 6            Mean_encoded_Route             33.641783
# 1                  Duration_min             13.085347
# 5          Mean_encoded_Airline             12.742877
# 2          Freq_encoded_Airline              7.795937
# 11                       arr_hr              6.705330
# 4            Freq_encoded_Route              6.161263
# 10                       dep_hr              4.601998
# 9           Label_encoded_Route              4.564760
# 13    arrival_timeOfDay_encoded              2.583292
# 0                   Total_Stops              2.308554
# 7         Label_encoded_Airline              2.112899
# 12  departure_timeOfDay_encoded              1.390282
# 3      Freq_encoded_Destination              1.317397
# 8     Label_encoded_Destination              0.988282

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7683002705872991 0.6379288736014788
#               feature_names_in_  feature_importances_
# 6            Mean_encoded_Route              0.665453
# 5          Mean_encoded_Airline              0.093253
# 1                  Duration_min              0.090620
# 2          Freq_encoded_Airline              0.050081
# 10                       dep_hr              0.029686
# 11                       arr_hr              0.028800
# 13    arrival_timeOfDay_encoded              0.010276
# 12  departure_timeOfDay_encoded              0.008525
# 4            Freq_encoded_Route              0.008204
# 7         Label_encoded_Airline              0.005669
# 9           Label_encoded_Route              0.005605
# 8     Label_encoded_Destination              0.001420
# 3      Freq_encoded_Destination              0.001341
# 0                   Total_Stops              0.001069

# %% [markdown]
# ## II

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night
df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])


one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
new_df = pd.concat([df,df_oneHotEncoded],axis=1)
new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

# %%
print(X.columns)
# Out:
# Index(['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
#        'Freq_encoded_Destination', 'Freq_encoded_Route',
#        'Mean_encoded_Airline', 'Mean_encoded_Route', 'Label_encoded_Airline',
#        'Label_encoded_Destination', 'Label_encoded_Route', 'dep_hr', 'arr_hr',
#        'departure_timeOfDay_encoded', 'arrival_timeOfDay_encoded',
#        'departure_timeOfDay_after_noon', 'departure_timeOfDay_early_morning',
#        'departure_timeOfDay_evening', 'departure_timeOfDay_late_night',
#        'departure_timeOfDay_morning', 'departure_timeOfDay_night',
#        'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning',
#        'arrival_timeOfDay_evening', 'arrival_timeOfDay_late_night',
#        'arrival_timeOfDay_morning', 'arrival_timeOfDay_night'],
#       dtype='object')

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7681904530985988 0.6376106185537618
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.664028
# 5                Mean_encoded_Airline              0.097592
# 1                        Duration_min              0.088550
# 2                Freq_encoded_Airline              0.045559
# 10                             dep_hr              0.025988
# 11                             arr_hr              0.024711
# 4                  Freq_encoded_Route              0.008002
# 13          arrival_timeOfDay_encoded              0.005687
# 9                 Label_encoded_Route              0.005387
# 7               Label_encoded_Airline              0.005306
# 12        departure_timeOfDay_encoded              0.004305
# 20       arrival_timeOfDay_after_noon              0.003205
# 24          arrival_timeOfDay_morning              0.002948
# 18        departure_timeOfDay_morning              0.002775
# 14     departure_timeOfDay_after_noon              0.002145
# 25            arrival_timeOfDay_night              0.001890
# 22          arrival_timeOfDay_evening              0.001654
# 16        departure_timeOfDay_evening              0.001596
# 8           Label_encoded_Destination              0.001541
# 3            Freq_encoded_Destination              0.001396
# 17     departure_timeOfDay_late_night              0.001211
# 21    arrival_timeOfDay_early_morning              0.001187
# 0                         Total_Stops              0.001148
# 15  departure_timeOfDay_early_morning              0.000984
# 19          departure_timeOfDay_night              0.000779
# 23       arrival_timeOfDay_late_night              0.000423

# %%
model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7049226109301652 0.6423930616286506
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.730786
# 5                Mean_encoded_Airline              0.155010
# 1                        Duration_min              0.036755
# 2                Freq_encoded_Airline              0.021772
# 11                             arr_hr              0.017723
# 10                             dep_hr              0.008854
# 4                  Freq_encoded_Route              0.008122
# 13          arrival_timeOfDay_encoded              0.005267
# 7               Label_encoded_Airline              0.004101
# 21    arrival_timeOfDay_early_morning              0.003623
# 24          arrival_timeOfDay_morning              0.002198
# 9                 Label_encoded_Route              0.001461
# 12        departure_timeOfDay_encoded              0.001267
# 14     departure_timeOfDay_after_noon              0.000758
# 22          arrival_timeOfDay_evening              0.000627
# 25            arrival_timeOfDay_night              0.000531
# 17     departure_timeOfDay_late_night              0.000356
# 18        departure_timeOfDay_morning              0.000320
# 20       arrival_timeOfDay_after_noon              0.000145
# 8           Label_encoded_Destination              0.000096
# 23       arrival_timeOfDay_late_night              0.000088
# 3            Freq_encoded_Destination              0.000071
# 16        departure_timeOfDay_evening              0.000036
# 15  departure_timeOfDay_early_morning              0.000031
# 0                         Total_Stops              0.000002
# 19          departure_timeOfDay_night              0.000000

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.7907441909318923 0.6065759476437993
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                                 weight          gain    total_gain  \
# Total_Stops                      125.0  6.491099e+06  8.113874e+08
# Duration_min                    1544.0  1.198381e+07  1.850301e+10
# Freq_encoded_Airline             232.0  8.695726e+07  2.017408e+10
# Freq_encoded_Destination          74.0  6.490674e+06  4.803098e+08
# Freq_encoded_Route               232.0  9.042155e+06  2.097780e+09
# Mean_encoded_Airline              86.0  1.518578e+08  1.305977e+10
# Mean_encoded_Route               189.0  8.354491e+08  1.578999e+11
# Label_encoded_Airline             51.0  1.658014e+07  8.455872e+08
# Label_encoded_Destination         16.0  3.449516e+06  5.519226e+07
# Label_encoded_Route              159.0  7.166880e+06  1.139534e+09
# dep_hr                           391.0  1.326301e+07  5.185837e+09
# arr_hr                           299.0  1.478675e+07  4.421239e+09
# departure_timeOfDay_encoded       23.0  6.126796e+06  1.409163e+08
# arrival_timeOfDay_encoded         54.0  2.258029e+07  1.219335e+09
# departure_timeOfDay_after_noon    34.0  1.280399e+07  4.353356e+08
# departure_timeOfDay_evening       23.0  5.793160e+06  1.332427e+08
# departure_timeOfDay_morning       49.0  7.638660e+06  3.742944e+08
# departure_timeOfDay_night          2.0  6.316645e+05  1.263329e+06
# arrival_timeOfDay_after_noon      32.0  1.374507e+07  4.398424e+08
# arrival_timeOfDay_evening         17.0  5.414136e+06  9.204031e+07
# arrival_timeOfDay_morning         26.0  2.188406e+07  5.689856e+08
# arrival_timeOfDay_night            8.0  6.733205e+06  5.386564e+07
#
#                                       cover  total_cover
# Total_Stops                      148.311996      18539.0
# Duration_min                    1245.745483    1923431.0
# Freq_encoded_Airline            1180.547363     273887.0
# Freq_encoded_Destination         145.310806      10753.0
# Freq_encoded_Route              1181.551758     274120.0
# Mean_encoded_Airline            2135.627930     183664.0
# Mean_encoded_Route              1771.883545     334886.0
# Label_encoded_Airline           1385.607788      70666.0
# Label_encoded_Destination         76.875000       1230.0
# Label_encoded_Route             1401.754761     222879.0
# dep_hr                          1014.383606     396624.0
# arr_hr                          1005.638794     300686.0
# departure_timeOfDay_encoded      678.956543      15616.0
# arrival_timeOfDay_encoded        558.629639      30166.0
# departure_timeOfDay_after_noon   935.529419      31808.0
# departure_timeOfDay_evening      898.000000      20654.0
# departure_timeOfDay_morning      351.918365      17244.0
# departure_timeOfDay_night       4957.000000       9914.0
# arrival_timeOfDay_after_noon     653.406250      20909.0
# arrival_timeOfDay_evening        783.647034      13322.0
# arrival_timeOfDay_morning        649.230774      16880.0
# arrival_timeOfDay_night          852.250000       6818.0

# %%
model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7682846560978025 0.6367455730983729
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route             37.335564
# 1                        Duration_min             12.809366
# 5                Mean_encoded_Airline             12.180031
# 2                Freq_encoded_Airline              6.541156
# 11                             arr_hr              5.750235
# 4                  Freq_encoded_Route              5.511799
# 10                             dep_hr              3.940768
# 9                 Label_encoded_Route              2.638977
# 7               Label_encoded_Airline              2.310331
# 8           Label_encoded_Destination              1.949076
# 3            Freq_encoded_Destination              1.748230
# 13          arrival_timeOfDay_encoded              1.666005
# 0                         Total_Stops              1.287259
# 12        departure_timeOfDay_encoded              0.780472
# 18        departure_timeOfDay_morning              0.553167
# 14     departure_timeOfDay_after_noon              0.400401
# 20       arrival_timeOfDay_after_noon              0.371329
# 16        departure_timeOfDay_evening              0.328984
# 23       arrival_timeOfDay_late_night              0.311243
# 25            arrival_timeOfDay_night              0.303498
# 24          arrival_timeOfDay_morning              0.291907
# 21    arrival_timeOfDay_early_morning              0.268039
# 15  departure_timeOfDay_early_morning              0.250113
# 17     departure_timeOfDay_late_night              0.207043
# 22          arrival_timeOfDay_evening              0.188838
# 19          departure_timeOfDay_night              0.076166

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7684012582066982 0.6378794241719702
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.662840
# 5                Mean_encoded_Airline              0.099288
# 1                        Duration_min              0.088636
# 2                Freq_encoded_Airline              0.045114
# 10                             dep_hr              0.025859
# 11                             arr_hr              0.024364
# 4                  Freq_encoded_Route              0.008098
# 13          arrival_timeOfDay_encoded              0.006058
# 9                 Label_encoded_Route              0.005462
# 7               Label_encoded_Airline              0.005142
# 12        departure_timeOfDay_encoded              0.004539
# 20       arrival_timeOfDay_after_noon              0.003098
# 24          arrival_timeOfDay_morning              0.002971
# 18        departure_timeOfDay_morning              0.002766
# 14     departure_timeOfDay_after_noon              0.002273
# 25            arrival_timeOfDay_night              0.001807
# 22          arrival_timeOfDay_evening              0.001665
# 16        departure_timeOfDay_evening              0.001595
# 3            Freq_encoded_Destination              0.001357
# 8           Label_encoded_Destination              0.001341
# 17     departure_timeOfDay_late_night              0.001147
# 21    arrival_timeOfDay_early_morning              0.001143
# 0                         Total_Stops              0.001082
# 15  departure_timeOfDay_early_morning              0.000976
# 19          departure_timeOfDay_night              0.000874
# 23       arrival_timeOfDay_late_night              0.000504

# %% [markdown]
# ## III

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night

df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['dep_day_of_week'] = df['DepartureDateTime'].dt.day_of_week 
df['arr_day_of_week'] = df['ArrivalDateTime'].dt.day_of_week 

df['dep_weekday'] = np.where(df["dep_day_of_week"].isin([5,6]),0,1)
df['arr_weekday'] = np.where(df["arr_day_of_week"].isin([5,6]),0,1)


df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
new_df = pd.concat([df,df_oneHotEncoded],axis=1)
new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

# %%
print(X.columns)
# Out:
# Index(['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
#        'Freq_encoded_Destination', 'Freq_encoded_Route',
#        'Mean_encoded_Airline', 'Mean_encoded_Route', 'Label_encoded_Airline',
#        'Label_encoded_Destination', 'Label_encoded_Route', 'dep_hr', 'arr_hr',
#        'departure_timeOfDay_encoded', 'arrival_timeOfDay_encoded',
#        'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday',
#        'departure_timeOfDay_after_noon', 'departure_timeOfDay_early_morning',
#        'departure_timeOfDay_evening', 'departure_timeOfDay_late_night',
#        'departure_timeOfDay_morning', 'departure_timeOfDay_night',
#        'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning',
#        'arrival_timeOfDay_evening', 'arrival_timeOfDay_late_night',
#        'arrival_timeOfDay_morning', 'arrival_timeOfDay_night'],
#       dtype='object')

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.8353956690344857 0.695753673163958
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.619282
# 5                Mean_encoded_Airline              0.086152
# 1                        Duration_min              0.072098
# 14                    dep_day_of_week              0.050387
# 2                Freq_encoded_Airline              0.042890
# 10                             dep_hr              0.022787
# 11                             arr_hr              0.021140
# 15                    arr_day_of_week              0.011726
# 16                        dep_weekday              0.010194
# 4                  Freq_encoded_Route              0.009267
# 9                 Label_encoded_Route              0.008863
# 12        departure_timeOfDay_encoded              0.006736
# 7               Label_encoded_Airline              0.005598
# 13          arrival_timeOfDay_encoded              0.004510
# 3            Freq_encoded_Destination              0.002755
# 8           Label_encoded_Destination              0.002641
# 28          arrival_timeOfDay_morning              0.002622
# 24       arrival_timeOfDay_after_noon              0.002533
# 0                         Total_Stops              0.002198
# 18     departure_timeOfDay_after_noon              0.002145
# 22        departure_timeOfDay_morning              0.002048
# 17                        arr_weekday              0.002043
# 29            arrival_timeOfDay_night              0.001904
# 20        departure_timeOfDay_evening              0.001855
# 26          arrival_timeOfDay_evening              0.001675
# 23          departure_timeOfDay_night              0.001095
# 21     departure_timeOfDay_late_night              0.000965
# 19  departure_timeOfDay_early_morning              0.000846
# 25    arrival_timeOfDay_early_morning              0.000565
# 27       arrival_timeOfDay_late_night              0.000479

# %%
model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.7389874971460669 0.6787921491856197
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.701815
# 5                Mean_encoded_Airline              0.141997
# 14                    dep_day_of_week              0.045535
# 1                        Duration_min              0.027453
# 2                Freq_encoded_Airline              0.026172
# 11                             arr_hr              0.011824
# 9                 Label_encoded_Route              0.011353
# 4                  Freq_encoded_Route              0.008987
# 10                             dep_hr              0.006880
# 16                        dep_weekday              0.005219
# 28          arrival_timeOfDay_morning              0.002190
# 13          arrival_timeOfDay_encoded              0.001978
# 27       arrival_timeOfDay_late_night              0.001972
# 7               Label_encoded_Airline              0.001410
# 15                    arr_day_of_week              0.000855
# 12        departure_timeOfDay_encoded              0.000817
# 24       arrival_timeOfDay_after_noon              0.000695
# 26          arrival_timeOfDay_evening              0.000573
# 25    arrival_timeOfDay_early_morning              0.000548
# 21     departure_timeOfDay_late_night              0.000437
# 3            Freq_encoded_Destination              0.000370
# 17                        arr_weekday              0.000360
# 18     departure_timeOfDay_after_noon              0.000170
# 0                         Total_Stops              0.000110
# 20        departure_timeOfDay_evening              0.000092
# 22        departure_timeOfDay_morning              0.000070
# 19  departure_timeOfDay_early_morning              0.000059
# 29            arrival_timeOfDay_night              0.000058
# 23          departure_timeOfDay_night              0.000000
# 8           Label_encoded_Destination              0.000000

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.8755851909701369 0.7035976022283565
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                                 weight         gain    total_gain  \
# Total_Stops                      104.0   13845911.0  1.439975e+09
# Duration_min                    1219.0   14592531.0  1.778830e+10
# Freq_encoded_Airline             224.0   87263280.0  1.954697e+10
# Freq_encoded_Destination          59.0   19764078.0  1.166081e+09
# Freq_encoded_Route               280.0   13434582.0  3.761683e+09
# Mean_encoded_Airline             104.0  131822376.0  1.370953e+10
# Mean_encoded_Route               249.0  638082304.0  1.588825e+11
# Label_encoded_Airline             70.0   13640507.0  9.548355e+08
# Label_encoded_Destination         16.0    9879319.0  1.580691e+08
# Label_encoded_Route              204.0    9159186.0  1.868474e+09
# dep_hr                           314.0   12112399.0  3.803293e+09
# arr_hr                           286.0   17001230.0  4.862352e+09
# departure_timeOfDay_encoded       24.0    7434007.5  1.784162e+08
# arrival_timeOfDay_encoded         50.0   27699458.0  1.384973e+09
# dep_day_of_week                  751.0   24025246.0  1.804296e+10
# arr_day_of_week                  333.0    7807941.0  2.600044e+09
# departure_timeOfDay_after_noon    27.0   15502210.0  4.185597e+08
# departure_timeOfDay_evening       27.0   12383675.0  3.343592e+08
# departure_timeOfDay_morning       43.0    6920616.0  2.975865e+08
# departure_timeOfDay_night          2.0    6205944.5  1.241189e+07
# arrival_timeOfDay_after_noon      28.0    7223801.5  2.022664e+08
# arrival_timeOfDay_evening         18.0   10317918.0  1.857225e+08
# arrival_timeOfDay_morning         22.0   23349534.0  5.136898e+08
# arrival_timeOfDay_night            5.0    4824791.5  2.412396e+07
#
#                                       cover  total_cover
# Total_Stops                      258.259613      26859.0
# Duration_min                    1250.506958    1524368.0
# Freq_encoded_Airline            1184.330322     265290.0
# Freq_encoded_Destination         240.932205      14215.0
# Freq_encoded_Route              1061.371460     297184.0
# Mean_encoded_Airline            1918.028809     199475.0
# Mean_encoded_Route              1436.943726     357799.0
# Label_encoded_Airline           1106.285767      77440.0
# Label_encoded_Destination        364.125000       5826.0
# Label_encoded_Route             1004.921570     205004.0
# dep_hr                          1084.722900     340603.0
# arr_hr                           799.293701     228598.0
# departure_timeOfDay_encoded     1263.416626      30322.0
# arrival_timeOfDay_encoded        646.979980      32349.0
# dep_day_of_week                  349.548615     262511.0
# arr_day_of_week                  506.618622     168704.0
# departure_timeOfDay_after_noon   354.814819       9580.0
# departure_timeOfDay_evening      929.148132      25087.0
# departure_timeOfDay_morning      923.441833      39708.0
# departure_timeOfDay_night       1212.000000       2424.0
# arrival_timeOfDay_after_noon     700.392883      19611.0
# arrival_timeOfDay_evening        818.388916      14731.0
# arrival_timeOfDay_morning       2188.318115      48143.0
# arrival_timeOfDay_night          845.799988       4229.0

# %%
model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.8386426134115561 0.7177296217797855
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route             32.799814
# 5                Mean_encoded_Airline             10.488620
# 14                    dep_day_of_week              9.889678
# 1                        Duration_min              8.050665
# 2                Freq_encoded_Airline              5.345923
# 4                  Freq_encoded_Route              4.791262
# 9                 Label_encoded_Route              4.170711
# 11                             arr_hr              3.986791
# 15                    arr_day_of_week              3.183384
# 10                             dep_hr              2.502915
# 0                         Total_Stops              2.049869
# 7               Label_encoded_Airline              2.039537
# 16                        dep_weekday              1.840789
# 17                        arr_weekday              1.762875
# 3            Freq_encoded_Destination              1.729970
# 13          arrival_timeOfDay_encoded              1.152397
# 8           Label_encoded_Destination              1.092751
# 12        departure_timeOfDay_encoded              0.626150
# 18     departure_timeOfDay_after_noon              0.488323
# 22        departure_timeOfDay_morning              0.412370
# 27       arrival_timeOfDay_late_night              0.346289
# 24       arrival_timeOfDay_after_noon              0.291296
# 29            arrival_timeOfDay_night              0.178091
# 28          arrival_timeOfDay_morning              0.174898
# 25    arrival_timeOfDay_early_morning              0.174602
# 20        departure_timeOfDay_evening              0.163398
# 19  departure_timeOfDay_early_morning              0.099265
# 26          arrival_timeOfDay_evening              0.097852
# 21     departure_timeOfDay_late_night              0.069515
# 23          departure_timeOfDay_night              0.000000

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.8358058931737522 0.6974533596098222
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.618665
# 5                Mean_encoded_Airline              0.091486
# 1                        Duration_min              0.070639
# 14                    dep_day_of_week              0.050854
# 2                Freq_encoded_Airline              0.040302
# 10                             dep_hr              0.022957
# 11                             arr_hr              0.020599
# 15                    arr_day_of_week              0.011319
# 16                        dep_weekday              0.010639
# 4                  Freq_encoded_Route              0.009571
# 9                 Label_encoded_Route              0.008825
# 12        departure_timeOfDay_encoded              0.006553
# 7               Label_encoded_Airline              0.005465
# 13          arrival_timeOfDay_encoded              0.004709
# 8           Label_encoded_Destination              0.002732
# 28          arrival_timeOfDay_morning              0.002546
# 24       arrival_timeOfDay_after_noon              0.002543
# 3            Freq_encoded_Destination              0.002399
# 17                        arr_weekday              0.002073
# 22        departure_timeOfDay_morning              0.002054
# 18     departure_timeOfDay_after_noon              0.002009
# 29            arrival_timeOfDay_night              0.001950
# 0                         Total_Stops              0.001877
# 20        departure_timeOfDay_evening              0.001824
# 26          arrival_timeOfDay_evening              0.001695
# 23          departure_timeOfDay_night              0.001024
# 21     departure_timeOfDay_late_night              0.000986
# 19  departure_timeOfDay_early_morning              0.000771
# 25    arrival_timeOfDay_early_morning              0.000497
# 27       arrival_timeOfDay_late_night              0.000436

# %% [markdown]
# ## IV

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)
# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night
df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['dep_month'] = df['DepartureDateTime'].dt.month
df['dep_day_of_month'] = df['DepartureDateTime'].dt.day

df['arr_month'] = df['ArrivalDateTime'].dt.month
df['arr_day_of_month'] = df['ArrivalDateTime'].dt.day

df['dep_day_of_week'] = df['DepartureDateTime'].dt.day_of_week 
df['arr_day_of_week'] = df['ArrivalDateTime'].dt.day_of_week 

df['dep_weekday'] = np.where(df["dep_day_of_week"].isin([5,6]),0,1)
df['arr_weekday'] = np.where(df["arr_day_of_week"].isin([5,6]),0,1)


df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
new_df = pd.concat([df,df_oneHotEncoded],axis=1)
new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

# %%
print(X.columns)
# Out:
# Index(['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
#        'Freq_encoded_Destination', 'Freq_encoded_Route',
#        'Mean_encoded_Airline', 'Mean_encoded_Route', 'Label_encoded_Airline',
#        'Label_encoded_Destination', 'Label_encoded_Route', 'dep_hr', 'arr_hr',
#        'departure_timeOfDay_encoded', 'arrival_timeOfDay_encoded',
#        'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday',
#        'dep_month', 'dep_day_of_month', 'arr_month', 'arr_day_of_month',
#        'departure_timeOfDay_after_noon', 'departure_timeOfDay_early_morning',
#        'departure_timeOfDay_evening', 'departure_timeOfDay_late_night',
#        'departure_timeOfDay_morning', 'departure_timeOfDay_night',
#        'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning',
#        'arrival_timeOfDay_evening', 'arrival_timeOfDay_late_night',
#        'arrival_timeOfDay_morning', 'arrival_timeOfDay_night'],
#       dtype='object')

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.9119419466219324 0.8342953345318137
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.583138
# 5                Mean_encoded_Airline              0.079951
# 1                        Duration_min              0.049339
# 19                   dep_day_of_month              0.047923
# 21                   arr_day_of_month              0.046281
# 2                Freq_encoded_Airline              0.038899
# 20                          arr_month              0.024817
# 18                          dep_month              0.024548
# 9                 Label_encoded_Route              0.019554
# 10                             dep_hr              0.013447
# 11                             arr_hr              0.013269
# 4                  Freq_encoded_Route              0.010411
# 14                    dep_day_of_week              0.008992
# 15                    arr_day_of_week              0.006908
# 7               Label_encoded_Airline              0.005266
# 13          arrival_timeOfDay_encoded              0.003132
# 8           Label_encoded_Destination              0.002866
# 12        departure_timeOfDay_encoded              0.002547
# 3            Freq_encoded_Destination              0.002186
# 16                        dep_weekday              0.002117
# 0                         Total_Stops              0.002098
# 22     departure_timeOfDay_after_noon              0.001964
# 32          arrival_timeOfDay_morning              0.001904
# 26        departure_timeOfDay_morning              0.001435
# 24        departure_timeOfDay_evening              0.001249
# 30          arrival_timeOfDay_evening              0.001227
# 33            arrival_timeOfDay_night              0.001089
# 28       arrival_timeOfDay_after_noon              0.000976
# 17                        arr_weekday              0.000666
# 23  departure_timeOfDay_early_morning              0.000466
# 29    arrival_timeOfDay_early_morning              0.000446
# 27          departure_timeOfDay_night              0.000409
# 31       arrival_timeOfDay_late_night              0.000304
# 25     departure_timeOfDay_late_night              0.000176

# %%
model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.8248432020119472 0.7986932633391627
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route              0.606068
# 5                Mean_encoded_Airline              0.142201
# 19                   dep_day_of_month              0.050204
# 21                   arr_day_of_month              0.038207
# 20                          arr_month              0.033522
# 18                          dep_month              0.030727
# 1                        Duration_min              0.022276
# 2                Freq_encoded_Airline              0.020400
# 11                             arr_hr              0.014855
# 4                  Freq_encoded_Route              0.009669
# 9                 Label_encoded_Route              0.008418
# 14                    dep_day_of_week              0.006269
# 0                         Total_Stops              0.003502
# 10                             dep_hr              0.002290
# 8           Label_encoded_Destination              0.002243
# 7               Label_encoded_Airline              0.001869
# 15                    arr_day_of_week              0.001805
# 32          arrival_timeOfDay_morning              0.001333
# 13          arrival_timeOfDay_encoded              0.000646
# 12        departure_timeOfDay_encoded              0.000624
# 29    arrival_timeOfDay_early_morning              0.000607
# 3            Freq_encoded_Destination              0.000586
# 30          arrival_timeOfDay_evening              0.000457
# 31       arrival_timeOfDay_late_night              0.000396
# 33            arrival_timeOfDay_night              0.000350
# 26        departure_timeOfDay_morning              0.000197
# 24        departure_timeOfDay_evening              0.000163
# 23  departure_timeOfDay_early_morning              0.000110
# 22     departure_timeOfDay_after_noon              0.000007
# 25     departure_timeOfDay_late_night              0.000000
# 27          departure_timeOfDay_night              0.000000
# 28       arrival_timeOfDay_after_noon              0.000000
# 16                        dep_weekday              0.000000
# 17                        arr_weekday              0.000000

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.9482279958647071 0.8403034607523993
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                                 weight          gain    total_gain  \
# Total_Stops                       84.0  1.457020e+07  1.223897e+09
# Duration_min                    1044.0  1.412395e+07  1.474541e+10
# Freq_encoded_Airline             235.0  7.292378e+07  1.713709e+10
# Freq_encoded_Destination          49.0  1.212284e+07  5.940194e+08
# Freq_encoded_Route               247.0  1.613929e+07  3.986406e+09
# Mean_encoded_Airline             118.0  1.221187e+08  1.441001e+10
# Mean_encoded_Route               238.0  6.681371e+08  1.590166e+11
# Label_encoded_Airline             74.0  2.009185e+07  1.486797e+09
# Label_encoded_Destination         20.0  1.188068e+07  2.376137e+08
# Label_encoded_Route              205.0  2.940696e+07  6.028428e+09
# dep_hr                           321.0  1.024904e+07  3.289943e+09
# arr_hr                           263.0  1.553088e+07  4.084622e+09
# departure_timeOfDay_encoded       31.0  8.727784e+06  2.705613e+08
# arrival_timeOfDay_encoded         49.0  1.773044e+07  8.687917e+08
# dep_day_of_week                  407.0  8.870963e+06  3.610482e+09
# arr_day_of_week                  188.0  6.100376e+06  1.146871e+09
# dep_month                        447.0  2.891833e+07  1.292649e+10
# dep_day_of_month                 495.0  4.345646e+07  2.151095e+10
# arr_day_of_month                 209.0  2.362981e+07  4.938630e+09
# departure_timeOfDay_after_noon    30.0  1.130006e+07  3.390018e+08
# departure_timeOfDay_evening       19.0  7.744594e+06  1.471473e+08
# departure_timeOfDay_morning       31.0  9.293583e+06  2.881011e+08
# departure_timeOfDay_night          2.0  1.648714e+06  3.297427e+06
# arrival_timeOfDay_after_noon      25.0  4.599193e+06  1.149798e+08
# arrival_timeOfDay_evening         15.0  1.265208e+07  1.897812e+08
# arrival_timeOfDay_morning         18.0  2.065552e+07  3.717993e+08
# arrival_timeOfDay_night            3.0  1.181813e+06  3.545439e+06
#
#                                       cover  total_cover
# Total_Stops                      150.285721      12624.0
# Duration_min                    1152.563232    1203276.0
# Freq_encoded_Airline            1011.757446     237763.0
# Freq_encoded_Destination         307.510193      15068.0
# Freq_encoded_Route              1131.813721     279558.0
# Mean_encoded_Airline            1564.000000     184552.0
# Mean_encoded_Route              1414.424316     336633.0
# Label_encoded_Airline            940.148621      69571.0
# Label_encoded_Destination        791.000000      15820.0
# Label_encoded_Route             1252.204834     256702.0
# dep_hr                           998.077881     320383.0
# arr_hr                          1145.471436     301259.0
# departure_timeOfDay_encoded      614.612915      19053.0
# arrival_timeOfDay_encoded        498.959198      24449.0
# dep_day_of_week                  338.110565     137611.0
# arr_day_of_week                  548.063843     103036.0
# dep_month                        556.427307     248723.0
# dep_day_of_month                 329.349487     163028.0
# arr_day_of_month                 871.186584     182078.0
# departure_timeOfDay_after_noon   710.133362      21304.0
# departure_timeOfDay_evening      284.947357       5414.0
# departure_timeOfDay_morning      729.322571      22609.0
# departure_timeOfDay_night       1920.500000       3841.0
# arrival_timeOfDay_after_noon     723.000000      18075.0
# arrival_timeOfDay_evening        303.133331       4547.0
# arrival_timeOfDay_morning        701.055542      12619.0
# arrival_timeOfDay_night          683.000000       2049.0

# %%
model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)
# Out:
# 0.9236163885562084 0.8481343501262277
#                     feature_names_in_  feature_importances_
# 6                  Mean_encoded_Route             27.054033
# 5                Mean_encoded_Airline              9.316487
# 18                          dep_month              8.437596
# 19                   dep_day_of_month              8.225847
# 21                   arr_day_of_month              7.675908
# 20                          arr_month              6.956852
# 1                        Duration_min              6.843646
# 2                Freq_encoded_Airline              4.269061
# 4                  Freq_encoded_Route              3.298229
# 9                 Label_encoded_Route              2.931280
# 11                             arr_hr              2.365624
# 14                    dep_day_of_week              2.009149
# 8           Label_encoded_Destination              1.720050
# 10                             dep_hr              1.623135
# 7               Label_encoded_Airline              1.479178
# 15                    arr_day_of_week              1.093038
# 0                         Total_Stops              1.001821
# 3            Freq_encoded_Destination              0.572478
# 13          arrival_timeOfDay_encoded              0.562344
# 12        departure_timeOfDay_encoded              0.470705
# 31       arrival_timeOfDay_late_night              0.331015
# 17                        arr_weekday              0.303018
# 22     departure_timeOfDay_after_noon              0.270770
# 16                        dep_weekday              0.252871
# 28       arrival_timeOfDay_after_noon              0.187148
# 26        departure_timeOfDay_morning              0.126434
# 24        departure_timeOfDay_evening              0.117208
# 23  departure_timeOfDay_early_morning              0.105757
# 30          arrival_timeOfDay_evening              0.105628
# 32          arrival_timeOfDay_morning              0.100611
# 33            arrival_timeOfDay_night              0.083874
# 29    arrival_timeOfDay_early_morning              0.063679
# 25     departure_timeOfDay_late_night              0.035696
# 27          departure_timeOfDay_night              0.009830

# %%
from sklearn.model_selection import cross_validate

# %%
def basic_model_selection(x,y,cross_folds,model):
    scores=[]
    names = []
    for i , j in model:
        cv_scores = cross_val_score(j, x, y,cv=cross_folds,n_jobs=5)
        scores.append(cv_scores)
        names.append(i)
    for k in range(len(scores)):
        print(names[k],scores[k].mean())

# %%
estimator = xgboost
X = X
y = y
scores = cross_validate(estimator, X, y, cv=3,
                       scoring=('r2', 'neg_mean_squared_error'),
                       return_train_score=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15076/3572559920.py in <module>
# ----> 1 estimator = xgboost
#       2 X = X
#       3 y = y
#       4 scores = cross_validate(estimator, X, y, cv=3,
#       5                        scoring=('r2', 'neg_mean_squared_error'),
#
# NameError: name 'xgboost' is not defined
